# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
url = 'https://www.boxofficemojo.com/alltime/weekends/?pagenum=m50&sort=opengross&p=.htm&order=DESC'
conn = 'mongodb+srv://generaluser:generaluser123@project2-ha8my.mongodb.net/Scrape?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# %%
# Retrieve page with the requests module
def requestUrl(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
results = requestUrl(url).find_all("table")[4]

# %%
# results

# %%
trResult=results.find_all("tr")
countLine = 0
countLine2 = 0
Foreign = []
exceptionId = [14,55,66,69,99]
initialUrl = 'https://www.boxofficemojo.com/movies/?page=intl&'
for one in range(len(trResult)):
    if countLine > 0:
        movieURL = initialUrl+trResult[one].find_all("td")[1].find("a")["href"][9:]
        movieName = trResult[one].find_all("td")[1].text
        movieRank = trResult[one].find_all("td")[0].text
        totalGross = trResult[one].find_all("td")[7].text
        if countLine in exceptionId:
            checkForeignUrl = requestUrl(movieURL).find_all("table")[8]   
        else:
            checkForeignUrl = requestUrl(movieURL).find_all("table")[7]
        trResult2=checkForeignUrl.find_all("tr")
#         print(trResult2)
        
        for two in range(len(trResult2)):
            if countLine2 > 2:
                countryName = trResult2[two].find_all("td")[0].text
                if countLine ==113:
                    countryTotalGross = trResult2[two].find_all("td")[2].text
                else:
                    countryTotalGross = trResult2[two].find_all("td")[5].text
                Foreign.append({
                    'country':countryName,
                    'total_gross':countryTotalGross
                    })
#                 print(countryName,countryTotalGross)
            countLine2 +=1
                
        post = {
                'movie_name': movieName,
                'total_gross': movieRank,
                'url_foreign': movieURL,
                'Foreign': Foreign
        }
        
    countLine +=1
    countLine2=0
    print(countLine, movieURL)
# Out:
# 1 https://www.boxofficemojo.com/movies/?page=intl&id=jurassicpark2.htm
# 2 https://www.boxofficemojo.com/movies/?page=intl&id=marvel2019.htm
# 3 https://www.boxofficemojo.com/movies/?page=intl&id=marvel0518.htm
# 4 https://www.boxofficemojo.com/movies/?page=intl&id=starwars7.htm
# 5 https://www.boxofficemojo.com/movies/?page=intl&id=starwars8.htm
# 6 https://www.boxofficemojo.com/movies/?page=intl&id=jurassicpark4.htm
# 7 https://www.boxofficemojo.com/movies/?page=intl&id=avengers11.htm
# 8 https://www.boxofficemojo.com/movies/?page=intl&id=marvel2017b.htm
# 9 https://www.boxofficemojo.com/movies/?page=intl&id=lionkingliveaction.htm
# 10 https://www.boxofficemojo.com/movies/?page=intl&id=avengers2.htm
# 11 https://www.boxofficemojo.com/movies/?page=intl&id=theincredibles2.htm
# 12 https://www.boxofficemojo.com/movies/?page=intl&id=marvel2016.htm
# 13 https://www.boxofficemojo.com/movies/?page=intl&id=beautyandthebeast2017.htm
# 14 https://www.boxofficemojo.com/movies/?page=intl&id=ironman3.htm
# 15 https://www.boxofficemojo.com/movies/?page=intl&id=harrypotter72.htm
# 16 https://www.boxofficemojo.com/movies/?page=intl&id=superman2015.htm
# 17 https://www.boxofficemojo.com/movies/?page=intl&id=batman3.htm
# 18 https://www.boxofficemojo.com/movies/?page=intl&id=darkknight.htm
# 19 https://www.boxofficemojo.com/movies/?page=intl&id=catchingfire.htm
# 20 https://www.boxofficemojo.com/movies/?page=intl&id=starwars2016.htm
# 21 https://www.boxofficemojo.com/movies/?page=intl&id=marvel2018a.htm
# 22 https://www.boxofficemojo.com/movies/?page=intl&id=hungergames.htm
# 23 https://www.boxofficemojo.com/movies/?page=intl&id=spiderman3.htm
# 24 https://www.boxofficemojo.com/movies/?page=intl&id=jurassicworldsequel.htm
# 25 https://www.boxofficemojo.com/movies/?page=intl&id=fast7.htm
