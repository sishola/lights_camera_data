# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests

import pandas as pd

from splinter import Browser

# %%
# URL to the page with movies that grosses > $50M
url = 'https://www.boxofficemojo.com/alltime/weekends/?pagenum=m50&sort=opengross&p=.htm&order=DESC'

#Scrape data on the page
tables = pd.read_html(url)

#Tables is a list of all the tables on the page, the required dataframe is stored in index 3
df = tables[3]

df.columns = ['Rank', 'Title', 'Studio', 'Opening', '% of Total', 'Theaters', 'Average', 'Total Gross', 'Date']

#Remove heading row that's saved as the first row
df = df.iloc[1:]

df.set_index('Rank', inplace=True)

df.head()
# Out:
#                              Title Studio       Opening % of Total Theaters  \
# Rank
# 1                Avengers: Endgame     BV  $357,115,007      41.6%     4662
# 2           Avengers: Infinity War     BV  $257,698,183      38.0%     4474
# 3     Star Wars: The Force Awakens     BV  $247,966,675      26.5%     4134
# 4         Star Wars: The Last Jedi     BV  $220,009,584      35.5%     4232
# 5                   Jurassic World   Uni.  $208,806,270      32.0%     4274
#
#       Average   Total Gross        Date
# Rank
# 1     $76,601  $858,373,000   4/26/2019
# 2     $57,599  $678,815,482   4/27/2018
# 3     $59,982  $936,662,225  12/18/2015
# 4     $51,987  $620,181,382  12/15/2017
# 5     $48,855  $652,270,625   6/12/2015

# %%
# Tab -  $40 - 50M, has the remaining data
url2 = 'https://www.boxofficemojo.com/alltime/weekends/?pagenum=m4050&sort=opengross&p=.htm&order=DESC'

tables2 = pd.read_html(url2)

#Tables is a list of all the tables on the page, the required dataframe is stored in index 3
df2 = tables2[3]

df2.columns = ['Rank', 'Title', 'Studio', 'Opening', '% of Total', 'Theaters', 'Average', 'Total Gross', 'Date']

#Remove heading row that's saved as the first row
df2 = df2.iloc[1:]

df2.set_index('Rank', inplace=True)


df2.head()
# Out:
#                            Title Studio      Opening % of Total Theaters  \
# Rank
# 249                      Taken 2    Fox  $49,514,769      35.4%     3661
# 250   How to Train Your Dragon 2    Fox  $49,451,322      27.9%     4253
# 251                  Rush Hour 3     NL  $49,100,158      35.0%     3778
# 252               Wreck-It Ralph     BV  $49,038,712      25.9%     3752
# 253                    Neighbors   Uni.  $49,033,915      32.7%     3279
#
#       Average   Total Gross       Date
# Rank
# 249   $13,525  $139,854,287  10/5/2012
# 250   $11,627  $177,002,924  6/13/2014
# 251   $12,996  $140,125,968  8/10/2007
# 252   $13,070  $189,422,889  11/2/2012
# 253   $14,954  $150,157,400   5/9/2014

# %%
#Concatenate the 2 dataframes
boxOffice_df = pd.concat([df,df2])

#We only need the top 250
boxOffice_df = boxOffice_df.iloc[0:250]

boxOffice_df.head()
# Out:
#                              Title Studio       Opening % of Total Theaters  \
# Rank
# 1                Avengers: Endgame     BV  $357,115,007      41.6%     4662
# 2           Avengers: Infinity War     BV  $257,698,183      38.0%     4474
# 3     Star Wars: The Force Awakens     BV  $247,966,675      26.5%     4134
# 4         Star Wars: The Last Jedi     BV  $220,009,584      35.5%     4232
# 5                   Jurassic World   Uni.  $208,806,270      32.0%     4274
#
#       Average   Total Gross        Date
# Rank
# 1     $76,601  $858,373,000   4/26/2019
# 2     $57,599  $678,815,482   4/27/2018
# 3     $59,982  $936,662,225  12/18/2015
# 4     $51,987  $620,181,382  12/15/2017
# 5     $48,855  $652,270,625   6/12/2015

# %%
#Replace abbreviated studio names with actual Studio names
print(boxOffice_df['Studio'].unique())

boxOffice_df['Studio'].replace(['BV', 'Uni.', 'WB', 'LGF' ,'Sony', 'Sum.' ,'LG/S', 'Fox' ,'Par.', 'WB (NL)', 'P/DW' ,'DW', 'NM' ,'NL', 'MGM'], ['Buena Vista', 'Universal', 'Warner Bros.', 'Lionsgate' ,'Sony / Columbia', 'Summit Entertainment' ,'Lionsgate' , '20th Century Fox' ,'Paramount', 'Warner Bros.', 'Paramount' ,'Dreamworks SKG', 'Newmarket' ,'New Line', 'MGM'], inplace=True)
# Out:
# ['BV' 'Uni.' 'WB' 'LGF' 'Sony' 'Sum.' 'LG/S' 'Fox' 'Par.' 'WB (NL)' 'P/DW'
#  'DW' 'NM' 'NL' 'MGM']

# %%
boxOffice_df.head()
# Out:
#                              Title       Studio       Opening % of Total  \
# Rank
# 1                Avengers: Endgame  Buena Vista  $357,115,007      41.6%
# 2           Avengers: Infinity War  Buena Vista  $257,698,183      38.0%
# 3     Star Wars: The Force Awakens  Buena Vista  $247,966,675      26.5%
# 4         Star Wars: The Last Jedi  Buena Vista  $220,009,584      35.5%
# 5                   Jurassic World    Universal  $208,806,270      32.0%
#
#      Theaters  Average   Total Gross        Date
# Rank
# 1        4662  $76,601  $858,373,000   4/26/2019
# 2        4474  $57,599  $678,815,482   4/27/2018
# 3        4134  $59,982  $936,662,225  12/18/2015
# 4        4232  $51,987  $620,181,382  12/15/2017
# 5        4274  $48,855  $652,270,625   6/12/2015

# %% [markdown]
# ## Retrieve Movie URLs

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=True)

# %%
# Retrieve page with the requests module
browser.visit(url)

# %%
# Create BeautifulSoup object
soup = bs(browser.html,'html.parser')

#Retrieve the required table
movieTable = soup.find_all("table")[4]

# %%
eachMovie = movieTable.find_all("tr")

movieList = []

for one in range(len(eachMovie)):
    movieURL = eachMovie[one].find_all("td")[1].find("a")["href"]
    movieName = eachMovie[one].find_all("td")[1].text
    movieRank = eachMovie[one].find_all("td")[0].text
    
    movieList.append({"movieURL" : "https://www.boxofficemojo.com" + movieURL, "movieName" : movieName, "movieRank": movieRank})
    
    #print(f"movieURL: {movieLink}, movieName: {movieName}, movieRank: {movieRank}")
    
movieList_df = pd.DataFrame( movieList)

movieList_df = movieList_df.iloc[1:250]


movieList_df#.head(15)
# Out:
#                                        movieName movieRank  \
# 1                              Avengers: Endgame         1
# 2                         Avengers: Infinity War         2
# 3                   Star Wars: The Force Awakens         3
# 4                       Star Wars: The Last Jedi         4
# 5                                 Jurassic World         5
# 6                          Marvel's The Avengers         6
# 7                                  Black Panther         7
# 8                           The Lion King (2019)         8
# 9                        Avengers: Age of Ultron         9
# 10                                 Incredibles 2        10
# 11                    Captain America: Civil War        11
# 12                   Beauty and the Beast (2017)        12
# 13                                    Iron Man 3        13
# 14   Harry Potter and the Deathly Hallows Part 2        14
# 26   https://www.boxofficemojo.com/movies/?id=newmo...
# 27   https://www.boxofficemojo.com/movies/?id=break...
# 28   https://www.boxofficemojo.com/movies/?id=break...
# 29   https://www.boxofficemojo.com/movies/?id=pirat...
# 30   https://www.boxofficemojo.com/movies/?id=pixar...
# ..                                                 ...
# 219  https://www.boxofficemojo.com/movies/?id=untit...
# 220  https://www.boxofficemojo.com/movies/?id=green...
# 221  https://www.boxofficemojo.com/movies/?id=wolve...
# 222  https://www.boxofficemojo.com/movies/?id=lego2...
# 223  https://www.boxofficemojo.com/movies/?id=batma...
# 224  https://www.boxofficemojo.com/movies/?id=paran...
# 225  https://www.boxofficemojo.com/movies/?id=super...
# 226  https://www.boxofficemojo.com/movies/?id=bourn...
# 227  https://www.boxofficemojo.com/movies/?id=insur...
# 228  https://www.boxofficemojo.com/movies/?id=irobo...
# 229  https://www.boxofficemojo.com/movies/?id=menin...
# 230  https://www.boxofficemojo.com/movies/?id=happy...
# 231  https://www.boxofficemojo.com/movies/?id=vanhe...
# 232  https://www.boxofficemojo.com/movies/?id=8mile...
# 233  https://www.boxofficemojo.com/movies/?id=menin...
# 234  https://www.boxofficemojo.com/movies/?id=bohem...
# 235  https://www.boxofficemojo.com/movies/?id=prome...
# 236  https://www.boxofficemojo.com/movies/?id=wante...
# 237  https://www.boxofficemojo.com/movies/?id=pixar...
# 238  https://www.boxofficemojo.com/movies/?id=juras...
# 239  https://www.boxofficemojo.com/movies/?id=villa...
# 240  https://www.boxofficemojo.com/movies/?id=chris...
# 241  https://www.boxofficemojo.com/movies/?id=2fast...
# 242  https://www.boxofficemojo.com/movies/?id=jacka...
# 243  https://www.boxofficemojo.com/movies/?id=mrand...
# 244  https://www.boxofficemojo.com/movies/?id=indep...
# 245  https://www.boxofficemojo.com/movies/?id=aquie...
# 246  https://www.boxofficemojo.com/movies/?id=bossb...
# 247  https://www.boxofficemojo.com/movies/?id=kingk...
# 248  https://www.boxofficemojo.com/movies/?id=great...
#
# [248 rows x 3 columns]

# %%
#Second tab

# Retrieve page with the requests module
browser.visit(url2)

# %%
# Create BeautifulSoup object
soup = bs(browser.html,'html.parser')
    
#Retrieve the required table
movieTable2 = soup.find_all("table")[4]

# %%
eachMovie2 = movieTable2.find_all("tr")

movieList2 = []

for one in range(len(eachMovie2)):
    movieURL = eachMovie2[one].find_all("td")[1].find("a")["href"]
    movieName = eachMovie2[one].find_all("td")[1].text
    movieRank = eachMovie2[one].find_all("td")[0].text
    
    movieList2.append({"movieURL" : "https://www.boxofficemojo.com" + movieURL, "movieName" : movieName, "movieRank": movieRank})
    
    #print(f"movieURL: {movieLink}, movieName: {movieName}, movieRank: {movieRank}")
    
movieList_df2 = pd.DataFrame( movieList2)

movieList_df2 = movieList_df2.iloc[1:3]


movieList_df2.head()
# Out:
#                     movieName movieRank  \
# 1                     Taken 2       249
# 2  How to Train Your Dragon 2       250
#
#                                             movieURL
# 1  https://www.boxofficemojo.com/movies/?id=taken...
# 2  https://www.boxofficemojo.com/movies/?id=howto...

# %%
#Concatenate the 2 dataframes
movieList_df = pd.concat([movieList_df,movieList_df2])

movieList_df.head()
# Out:
#                       movieName movieRank  \
# 1             Avengers: Endgame         1
# 2        Avengers: Infinity War         2
# 3  Star Wars: The Force Awakens         3
# 4      Star Wars: The Last Jedi         4
# 5                Jurassic World         5
#
#                                             movieURL
# 1  https://www.boxofficemojo.com/movies/?id=marve...
# 2  https://www.boxofficemojo.com/movies/?id=marve...
# 3  https://www.boxofficemojo.com/movies/?id=starw...
# 4  https://www.boxofficemojo.com/movies/?id=starw...
# 5  https://www.boxofficemojo.com/movies/?id=juras...

# %%
movieList_df.set_index('movieRank', inplace=True)

movieList_df
# Out:
#                                              movieName  \
# movieRank
# 1                                    Avengers: Endgame
# 2                               Avengers: Infinity War
# 3                         Star Wars: The Force Awakens
# 4                             Star Wars: The Last Jedi
# 5                                       Jurassic World
# 6                                Marvel's The Avengers
# 7                                        Black Panther
# 8                                 The Lion King (2019)
# 9                              Avengers: Age of Ultron
# 10                                       Incredibles 2
# 11                          Captain America: Civil War
# 12                         Beauty and the Beast (2017)
# 13                                          Iron Man 3
# 14         Harry Potter and the Deathly Hallows Part 2
# 15                  Batman v Superman: Dawn of Justice
# 16                               The Dark Knight Rises
# 17                                     The Dark Knight
# 18                     The Hunger Games: Catching Fire
# 19                        Rogue One: A Star Wars Story
# 20                                     Captain Marvel
# 21                                    The Hunger Games
# 22                                        Spider-Man 3
# 23                      Jurassic World: Fallen Kingdom
# 24                                           Furious 7
# 25                      Guardians of the Galaxy Vol. 2
# 26                         The Twilight Saga: New Moon
# 27             The Twilight Saga: Breaking Dawn Part 2
# 28             The Twilight Saga: Breaking Dawn Part 1
# 29          Pirates of the Caribbean: Dead Man's Chest
# 30                                        Finding Dory
# ...                                                ...
# 221                                      The Wolverine
# 222                              The LEGO Batman Movie
# 223                                     Batman Forever
# 224                              Paranormal Activity 3
# 225                                   Superman Returns
# 226                               The Bourne Supremacy
# 227                    The Divergent Series: Insurgent
# 228                                           I, Robot
# 229                                    Men in Black II
# 230                                        Home (2015)
# 231                                        Van Helsing
# 232                                             8 Mile
# 233                                       Men in Black
# 234                                  Bohemian Rhapsody
# 235                                         Prometheus
# 236                                             Wanted
# 237                                               Coco
# 238                                  Jurassic Park III
# 239                                        The Village
# 240                                            Dunkirk
# 241                                   2 Fast 2 Furious
# 242                                        Jackass 3-D
# 243                                   Mr. & Mrs. Smith
# 244                                   Independence Day
# 245                                      A Quiet Place
# 246                                      The Boss Baby
# 247                                          King Kong
# 248                            The Great Gatsby (2013)
# 249                                            Taken 2
# 250                         How to Train Your Dragon 2
#
#                                                     movieURL
# movieRank
# 1          https://www.boxofficemojo.com/movies/?id=marve...
# 2          https://www.boxofficemojo.com/movies/?id=marve...
# 3          https://www.boxofficemojo.com/movies/?id=starw...
# 4          https://www.boxofficemojo.com/movies/?id=starw...
# 5          https://www.boxofficemojo.com/movies/?id=juras...
# 6          https://www.boxofficemojo.com/movies/?id=aveng...
# 7          https://www.boxofficemojo.com/movies/?id=marve...
