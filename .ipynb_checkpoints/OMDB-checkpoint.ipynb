# %%
# Dependencies
import requests
import pymongo
import pandas as pd

# %%
# Box Office Mojo URL for films grossing $50M+
url = 'https://www.boxofficemojo.com/alltime/weekends/?pagenum=m50&sort=opengross&p=.htm&order=DESC'
# Box Office Mojo URL for films grossing $50-40M
url2 = 'https://www.boxofficemojo.com/alltime/weekends/?pagenum=m4050&sort=opengross&p=.htm&order=DESC'
# Box Office Mojo URL for all time box office adjusted for inflation
url3 = 'https://www.boxofficemojo.com/alltime/adjusted.htm'
# Box Office Mojo URL for all time box office unadjusted for inflation
url4 = 'https://www.boxofficemojo.com/alltime/adjusted.htm?sort=gross&order=DESC&adjust_yr=2019&p=.htm'

# %%
# Using pandas, find all tables on the url page
tables = pd.read_html(url)

# Since tables is a list of all the tables on the page, the required dataframe is stored in index 3
df = tables[3]
# Set the column names
df.columns = ['Rank', 'Title', 'Studio', 'Opening', '% of Total', 'Theaters', 'Average', 'Total Gross', 'Date']
# Remove first row since unnecessary row
df = df.iloc[1:]

# %%
# Using pandas, find all tables on the url page
tables2 = pd.read_html(url2)

# Since tables is a list of all the tables on the page, the required dataframe is stored in index 3
df2 = tables2[3]
# Set the column names
df2.columns = ['Rank', 'Title', 'Studio', 'Opening', '% of Total', 'Theaters', 'Average', 'Total Gross', 'Date']
# Remove first row since unnecessary row
df2 = df2.iloc[1:]

# %%
# Combine both dataframes into one using concat
boxOffice_df = pd.concat([df,df2])
# Extract only the top 250 highest grossing films
boxOffice_df = boxOffice_df.iloc[0:250]

#Replace abbreviated studio names with actual studio names
boxOffice_df['Studio'].replace(['BV', 'Uni.', 'WB', 'LGF' ,'Sony', 'Sum.' ,'LG/S', 'Fox' ,
                                'Par.', 'WB (NL)', 'P/DW' ,'DW', 'NM' ,'NL', 'MGM'], 
                               ['Buena Vista', 'Universal', 'Warner Bros.', 'Lionsgate' ,'Sony / Columbia', 
                                'Summit Entertainment' ,'Lionsgate' , '20th Century Fox' ,'Paramount', 'Warner Bros.',
                                'Paramount' ,'Dreamworks SKG', 'Newmarket' ,'New Line', 'MGM'], inplace=True)

# %%
# Create a list of all the columns that need to be converted
string_to_float = ['Opening','Average','Total Gross']

# Initialize empty lists for new columns
opening = []
average = []
total_gross = []

# For each column that needs to be converted
for column in string_to_float:
    # For each row in the specified column
    for amount in boxOffice_df[column]:
        # Remove the $ symbol
        amount = amount[1:]
        # Remove all commas
        amount = amount.replace(',','')
        # Use if statetements to add the stripped amount to the correct list
        if column == 'Opening':
            opening.append(amount) 
        elif column == 'Average':
            average.append(amount)
        else:
            total_gross.append(amount)
    
# Update the columns with the integer amounts
boxOffice_df['Opening'] = pd.to_numeric(opening)
boxOffice_df['Average'] = pd.to_numeric(average)
boxOffice_df['Total Gross'] = pd.to_numeric(total_gross)
boxOffice_df["Rank"] = pd.to_numeric(boxOffice_df["Rank"])

# %%
# Using pandas, find all tables on the url page
tables3 = pd.read_html(url3)

# Since tables is a list of all the tables on the page, the required dataframe is stored in index 1
df3 = tables3[1]

# Set the column names
df3.columns = ['Rank', 'Title', 'Studio', 'Adjusted Gross', 'Unadjusted Gross', 'Year']
# Remove first row since unnecessary row
df3 = df3.iloc[1:]

# Extract only the top 250 highest grossing films
df3 = df3.iloc[0:250]

df3['Rank'] = pd.to_numeric(df3['Rank'])

df3['Studio'].replace(['BV', 'Uni.', 'WB', 'LGF' ,'Sony', 'Sum.' ,'LG/S', 'Fox' , 'Dis.','TriS', 'Col.',
                                'Par.', 'WB (NL)', 'P/DW' ,'DW', 'NM' ,'NL', 'MGM','UA','AIP','Selz.' ], 
                               ['Buena Vista', 'Universal', 'Warner Bros.', 'Lionsgate' ,'Sony / Columbia', 
                                'Summit Entertainment' ,'Lionsgate' , '20th Century Fox' ,'Buena Vista', 'Sony / Columbia',
                                'Sony / Columbia', 'Paramount', 'Warner Bros.','Paramount' ,'Dreamworks SKG', 'Newmarket' ,
                                'New Line', 'MGM','MGM','American International Pictures','Selznick' ], inplace=True)

# %%
# Using pandas, find all tables on the url page
tables4 = pd.read_html(url4)

# Since tables is a list of all the tables on the page, the required dataframe is stored in index 1
df4 = tables4[1]

# Set the column names
df4.columns = ['Rank','Row', 'Title', 'Studio', 'Adjusted Gross', 'Unadjusted Gross', 'Year']
# Remove first row since unnecessary row
df4 = df4.iloc[1:]

# Extract only the top 250 highest grossing films
df4 = df4.iloc[0:250]


df4 = df4[['Rank', 'Title', 'Studio', 'Adjusted Gross', 'Unadjusted Gross', 'Year']]

fixed_unadj = []

for adj,unadj in zip(df4['Adjusted Gross'],df4['Unadjusted Gross']):
    if unadj == '2019':
        unadj = adj
        unadj = unadj[1:]
        unadj = unadj.replace(",","")
        fixed_unadj.append(unadj)
    else:
        unadj = unadj[1:]
        unadj = unadj.replace(",","")
        fixed_unadj.append(unadj)
        
df4['Unadjusted Gross'] = fixed_unadj
df4['Unadjusted Gross'] = pd.to_numeric(df4['Unadjusted Gross'])
df4['Rank'] = pd.to_numeric(df4['Rank'])

df4['Studio'].replace(['BV', 'Uni.', 'WB', 'LGF' ,'Sony', 'Sum.' ,'LG/S', 'Fox' , 'Dis.','TriS', 'Col.',
                                'Par.', 'WB (NL)', 'P/DW' ,'DW', 'NM' ,'NL', 'MGM','UA','AIP'], 
                               ['Buena Vista', 'Universal', 'Warner Bros.', 'Lionsgate' ,'Sony / Columbia', 
                                'Summit Entertainment' ,'Lionsgate' , '20th Century Fox' ,'Buena Vista', 'Sony / Columbia',
                                'Sony / Columbia', 'Paramount', 'Warner Bros.','Paramount' ,'Dreamworks SKG', 'Newmarket' ,
                                'New Line', 'MGM','MGM','American International Pictures'], inplace=True)

df4.dtypes
# Out:
# Rank                 int64
# Title               object
# Studio              object
# Adjusted Gross      object
# Unadjusted Gross     int64
# Year                object
# dtype: object

# %%
adjusted_df = df3.merge(df4,left_on = 'Rank',right_on='Rank')
adjusted_df.head()
# Out:
#    Rank                      Title_x          Studio_x Adjusted Gross_x  \
# 0     1           Gone with the Wind               MGM   $1,822,598,200
# 1     2                    Star Wars  20th Century Fox   $1,604,857,600
# 2     3           The Sound of Music  20th Century Fox   $1,283,791,300
# 3     4  E.T.: The Extra-Terrestrial         Universal   $1,278,107,600
# 4     5                      Titanic         Paramount   $1,221,303,800
#
#   Unadjusted Gross_x Year_x                       Title_y          Studio_y  \
# 0       $200,852,579  1939^  Star Wars: The Force Awakens       Buena Vista
# 1       $460,998,007  1977^             Avengers: Endgame       Buena Vista
# 2       $159,287,539  1965^                        Avatar  20th Century Fox
# 3       $435,110,554  1982^                 Black Panther       Buena Vista
# 4       $659,363,944  1997^        Avengers: Infinity War       Buena Vista
#
#   Adjusted Gross_y  Unadjusted Gross_y Year_y
# 0     $974,117,000           936662225   2015
# 1     $858,373,000           858373000   2015
# 2     $876,759,300           760507625  2009^
# 3     $687,213,600           700059566   2018
# 4     $652,501,800           678815482   2018

# %%
adjusted_df = df3.merge(df4,left_on = 'Rank',right_on='Rank')
adjusted_df = adjusted_df[['Rank', 'Title_x', 'Adjusted Gross_x', 'Title_y', 'Unadjusted Gross_y']]

adjusted_gross = []
for amount in adjusted_df['Adjusted Gross_x']:
    # Remove the $ symbol
    amount = amount[1:]
    # Remove all commas
    amount = amount.replace(',','')
    # Append stripped number to list
    adjusted_gross.append(amount)
    
adjusted_df['Adjusted Gross_x'] = adjusted_gross
adjusted_df['Adjusted Gross_x'] = pd.to_numeric(adjusted_df['Adjusted Gross_x'])
adjusted_df.head()
# Out:
#    Rank                      Title_x  Adjusted Gross_x  \
# 0     1           Gone with the Wind        1822598200
# 1     2                    Star Wars        1604857600
# 2     3           The Sound of Music        1283791300
# 3     4  E.T.: The Extra-Terrestrial        1278107600
# 4     5                      Titanic        1221303800
#
#                         Title_y  Unadjusted Gross_y
# 0  Star Wars: The Force Awakens           936662225
# 1             Avengers: Endgame           858373000
# 2                        Avatar           760507625
# 3                 Black Panther           700059566
# 4        Avengers: Infinity War           678815482

# %%
# Online Movie Database (OMDB) API URL including API Key and full plot
api_url = "http://www.omdbapi.com/?apikey=57e34fb6&plot=full"

# MongoDB connection
conn = 'mongodb+srv://generaluser:generaluser123@project2-ha8my.mongodb.net/db?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# %%
movie_data = []
wrong_movies= {"MIB 3":'tt1409024',
               "Fast & Furious Presents: Hobbs & Shaw":'tt6806448',
               "Star Wars: The Force Awakens": 'tt2488496',
               "Marvel's The Avengers":'tt0848228',
               "The Divergent Series: Insurgent":'tt2908446',
               "Dr. Seuss' The Lorax":'tt1482459',
               "Monsters Vs. Aliens":'tt0892782',
               "Jackass 3-D":'tt1116184',
               "Dr. Seuss' The Grinch (2018)":'tt2709692',
               "Fantastic Four: Rise of the Silver Surfer":'tt0486576',
               "Kramer Vs. Kramer":'tt0079417',
               "Mission: Impossible":'tt0117060',
               "The Amityville Horror":'tt0078767',
               "Three Men and a Baby":'tt0094137'}

for title in df4['Title']:
    if title in wrong_movies:
        movie_id = wrong_movies[title]
        movie = requests.get(api_url + '&i=' + movie_id).json()
        if movie['Response'] == "True":
            movie_data.append(movie)
    elif "(" in title:
        year = title[-5:][:-1]
        title = title[:-6]
        movie = requests.get(api_url + '&t=' + title + '&y=' + year).json()
        if movie['Response'] == "True":
            movie_data.append(movie)
    else:
        movie = requests.get(api_url + '&t=' + title).json()
        if movie['Response'] == "True":
            movie_data.append(movie)

# %%
for movie in movie_data:
    print(movie['Title'])
# Out:
# Star Wars: Episode VII - The Force Awakens
# Avengers: Endgame
# Avatar
# Black Panther
# Avengers: Infinity War
# Titanic
# Jurassic World
# The Avengers
# Star Wars: The Last Jedi
# Incredibles 2
# The Lion King
# The Dark Knight
# Rogue One: A Star Wars Story
# Beauty and the Beast
# Finding Dory
# Star Wars: Episode I - The Phantom Menace
# Star Wars: Episode IV - A New Hope
# Avengers: Age of Ultron
# The Dark Knight Rises
# Shrek 2
# E.T. the Extra-Terrestrial
# Toy Story 4
# Captain Marvel
# The Hunger Games: Catching Fire
# Pirates of the Caribbean: Dead Man's Chest
# The Lion King
# Jurassic World: Fallen Kingdom
# Toy Story 3
# Wonder Woman
# Iron Man 3
# Captain America: Civil War
# The Hunger Games
# Jumanji: Welcome to the Jungle
# Spider-Man
# Jurassic Park
# Transformers: Revenge of the Fallen
# Frozen
# Spider-Man: Far from Home
# Guardians of the Galaxy Vol. 2
# Harry Potter and the Deathly Hallows: Part 2
# Finding Nemo
# Star Wars: Episode III - Revenge of the Sith
# The Lord of the Rings: The Return of the King
# Spider-Man 2
# The Passion of the Christ
# The Secret Life of Pets
# Despicable Me 2
# The Jungle Book
# Deadpool
# Inside Out
# Aladdin
# Furious 7
# Transformers: Dark of the Moon
# American Sniper
# The Lord of the Rings: The Two Towers
# Zootopia
# The Hunger Games: Mockingjay - Part 1
# Spider-Man 3
# Minions
# Aquaman
# Spider-Man: Homecoming
# Alice in Wonderland
# Guardians of the Galaxy
# Forrest Gump
# Batman v Superman: Dawn of Justice
# It
# Suicide Squad
# Deadpool 2
# Shrek the Third
# Transformers
# Iron Man
# Harry Potter and the Sorcerer's Stone
# Indiana Jones and the Kingdom of the Crystal Skull
# The Lord of the Rings: The Fellowship of the Ring
# Thor: Ragnarok
# Iron Man 2
# Star Wars: Episode II - Attack of the Clones
# Pirates of the Caribbean: At World's End
# Star Wars: Episode VI - Return of the Jedi
# Independence Day
# Pirates of the Caribbean: The Curse of the Black Pearl
# Skyfall
# The Hobbit: An Unexpected Journey
# Harry Potter and the Half-Blood Prince
# The Twilight Saga: Eclipse
# The Twilight Saga: New Moon
# Harry Potter and the Deathly Hallows: Part 1
# The Sixth Sense
# Up
# Inception
# The Twilight Saga: Breaking Dawn - Part 2
# Harry Potter and the Order of the Phoenix
# The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Man of Steel
# Star Wars: Episode V - The Empire Strikes Back
# Harry Potter and the Goblet of Fire
# Monsters, Inc.
# Home Alone
# The Hunger Games: Mockingjay - Part 2
# The Matrix Reloaded
# The Twilight Saga: Breaking Dawn - Part 1
# Meet the Fockers
# The Hangover
# Gravity
# Monsters University
# Shrek
# Harry Potter and the Chamber of Secrets
# The Amazing Spider-Man
# The Incredibles
# How the Grinch Stole Christmas
# Jaws
# The Hobbit: The Desolation of Smaug
# The Lego Movie
# Star Trek
# I Am Legend
# The Blind Side
# The Hangover Part II
# Despicable Me
# Batman
# Night at the Museum
# Men in Black
# Harry Potter and the Prisoner of Azkaban
# Raiders of the Lost Ark
# Toy Story 2
# Cars
# Bruce Almighty
# Ghostbusters
# Twister
# My Big Fat Greek Wedding
# Beverly Hills Cop
# X-Men: The Last Stand
# War of the Worlds
# Cast Away
# The Exorcist
# The Lost World: Jurassic Park
# Signs
# Hancock
# The Bourne Ultimatum
# Rush Hour 2
# Mrs. Doubtfire
# Beauty and the Beast
# King Kong
# Ghost
# The Da Vinci Code
# Aladdin
# Saving Private Ryan
# Mission: Impossible II
# X2: X-Men United
# Austin Powers in Goldmember
# Back to the Future
# Wedding Crashers
# Batman Begins
# Charlie and the Chocolate Factory
# Austin Powers: The Spy Who Shagged Me
# Terminator 2: Judgment Day
# The Mummy Returns
# Armageddon
# Gone with the Wind
# Pearl Harbor
# Indiana Jones and the Last Crusade
# Toy Story
# Men in Black II
# Grease
# Gladiator
# Snow White and the Seven Dwarfs
# Dances with Wolves
# Batman Forever
# The Fugitive
# Ocean's Eleven
# What Women Want
# The Perfect Storm
# Liar Liar
# Jurassic Park III
# Mission: Impossible
# Planet of the Apes
# Indiana Jones and the Temple of Doom
# Top Gun
# Pretty Woman
# Tootsie
# There's Something About Mary
# Crocodile Dundee
# Apollo 13
# Home Alone 2: Lost in New York
# Air Force One
# Rain Man
# The Matrix
# Tarzan
# 3 Men and a Baby
# Robin Hood: Prince of Thieves
# Big Daddy
# Batman Returns
# A Bug's Life
# The Waterboy
# The Sound of Music
# The Firm
# Fatal Attraction
# Who Framed Roger Rabbit
# The Sting
# Jerry Maguire
# Beverly Hills Cop II
# Gremlins
# Rambo: First Blood Part II
# As Good as It Gets
# Lethal Weapon 2
# True Lies
# 101 Dalmatians
# The Santa Clause
# Lethal Weapon 3
# The Jungle Book
# National Lampoon's Animal House
# Pocahontas
# A Few Good Men
# Look Who's Talking
# Sister Act
# Platoon
# Teenage Mutant Ninja Turtles
# Close Encounters of the Third Kind
# The Godfather
# Superman
# Honey, I Shrunk the Kids
# An Officer and a Gentleman
# Rocky IV
# Smokey and the Bandit
# Rocky III
# Blazing Saddles
# On Golden Pond
# Rocky
# The Towering Inferno
# American Graffiti
# The Rocky Horror Picture Show
# Doctor Zhivago
# Porky's
# One Flew Over the Cuckoo's Nest
# Terms of Endearment
# Superman II
# Love Story
# Kramer vs. Kramer
# The Graduate
# 9 to 5
# Butch Cassidy and the Sundance Kid
# Mary Poppins
# Bambi
# Stir Crazy
# Airport
# Arthur
# Saturday Night Fever
# Lady and the Tramp
# Cinderella
# Peter Pan
# The Amityville Horror

# %%
movie_df1 = pd.DataFrame(movie_data)
movie_df1
# Out:
#                                                 Actors  \
# 0    Harrison Ford, Mark Hamill, Carrie Fisher, Ada...
# 1    Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 2    Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 3    Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# 4    Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 5    Leonardo DiCaprio, Kate Winslet, Billy Zane, K...
# 6    Chris Pratt, Bryce Dallas Howard, Irrfan Khan,...
# 7    Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# 8    Mark Hamill, Carrie Fisher, Adam Driver, Daisy...
# 9    Craig T. Nelson, Holly Hunter, Sarah Vowell, H...
# 10   Chiwetel Ejiofor, John Oliver, James Earl Jone...
# 11   Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 12   Felicity Jones, Diego Luna, Alan Tudyk, Donnie...
# 13      Emma Watson, Dan Stevens, Luke Evans, Josh Gad
# 14   Ellen DeGeneres, Albert Brooks, Ed O'Neill, Ka...
# 15   Liam Neeson, Ewan McGregor, Natalie Portman, J...
# 16   Mark Hamill, Harrison Ford, Carrie Fisher, Pet...
# 17   Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 18   Christian Bale, Gary Oldman, Tom Hardy, Joseph...
# 19   Mike Myers, Eddie Murphy, Cameron Diaz, Julie ...
# 20   Dee Wallace, Henry Thomas, Peter Coyote, Rober...
# 21        Tom Hanks, Tim Allen, Annie Potts, Tony Hale
# 22   Brie Larson, Samuel L. Jackson, Ben Mendelsohn...
# 23   Jennifer Lawrence, Liam Hemsworth, Jack Quaid,...
# 24   Johnny Depp, Orlando Bloom, Keira Knightley, J...
# 25   Rowan Atkinson, Matthew Broderick, Niketa Cala...
# 26   Chris Pratt, Bryce Dallas Howard, Rafe Spall, ...
# 27       Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty
# 28   Gal Gadot, Chris Pine, Connie Nielsen, Robin W...
# 29   Robert Downey Jr., Gwyneth Paltrow, Don Cheadl...
# ..                                                 ...
# 220  Richard Gere, Debra Winger, David Keith, Rober...
# 221  Sylvester Stallone, Talia Shire, Burt Young, C...
# 222  Burt Reynolds, Sally Field, Jerry Reed, Mike H...
# 223  Sylvester Stallone, Talia Shire, Burt Young, C...
# 224  Cleavon Little, Gene Wilder, Slim Pickens, Har...
# 225  Katharine Hepburn, Henry Fonda, Jane Fonda, Do...
# 226  Sylvester Stallone, Talia Shire, Burt Young, C...
# 227  Steve McQueen, Paul Newman, William Holden, Fa...
# 228  Richard Dreyfuss, Ron Howard, Paul Le Mat, Cha...
# 229  Tim Curry, Susan Sarandon, Barry Bostwick, Ric...
# 230  Omar Sharif, Julie Christie, Geraldine Chaplin...
# 231  Dan Monahan, Mark Herrier, Wyatt Knight, Roger...
# 232  Jack Nicholson, Louise Fletcher, Will Sampson,...
# 233  Shirley MacLaine, Debra Winger, Jack Nicholson...
# 234  Gene Hackman, Christopher Reeve, Ned Beatty, J...
# 235  Ali MacGraw, Ryan O'Neal, John Marley, Ray Mil...
# 236  Dustin Hoffman, Meryl Streep, Jane Alexander, ...
# 237  Anne Bancroft, Dustin Hoffman, Katharine Ross,...
# 238  Jane Fonda, Lily Tomlin, Dolly Parton, Dabney ...
# 239  Paul Newman, Robert Redford, Katharine Ross, S...
# 240  Julie Andrews, Dick Van Dyke, David Tomlinson,...
# 241  Hardie Albright, Stan Alexander, Bobette Audre...
# 242  Gene Wilder, Richard Pryor, Georg Stanford Bro...
# 243  Burt Lancaster, Dean Martin, Jean Seberg, Jacq...
# 244  Russell Brand, Helen Mirren, Greta Gerwig, Jen...
# 245  John Travolta, Karen Lynn Gorney, Barry Miller...
# 246  Peggy Lee, Larry Roberts, Bill Baucom, Verna F...
# 247  Ilene Woods, Eleanor Audley, Verna Felton, Cla...
# 248  Bobby Driscoll, Kathryn Beaumont, Hans Conried...
# 249  James Brolin, Margot Kidder, Rod Steiger, Don ...
#
#                                                 Awards     BoxOffice  \
# 0    Nominated for 5 Oscars. Another 57 wins & 123 ...  $936,658,640
# 1                                                  N/A           N/A
# 2     Won 3 Oscars. Another 85 wins & 128 nominations.  $749,700,000
# 3                                      14 nominations.  $501,105,037
# 4                                                  N/A  $664,987,816
# 5    Won 11 Oscars. Another 111 wins & 77 nominations.           N/A
# 6                            14 wins & 57 nominations.  $528,757,749
# 7    Nominated for 1 Oscar. Another 38 wins & 79 no...  $623,279,547
# 8    Nominated for 4 Oscars. Another 12 wins & 71 n...  $619,117,636
# 9                                                  N/A           N/A
# 10                                                 N/A           N/A
# 11   Won 2 Oscars. Another 152 wins & 155 nominations.  $533,316,061
# 12   Nominated for 2 Oscars. Another 23 wins & 78 n...  $532,171,696
# 13   Nominated for 2 Oscars. Another 12 wins & 65 n...  $503,974,884
# 14   Nominated for 1 BAFTA Film Award. Another 15 w...  $486,292,984
# 15   Nominated for 3 Oscars. Another 26 wins & 65 n...  $431,000,000
# 16     Won 6 Oscars. Another 50 wins & 28 nominations.           N/A
# 17                            7 wins & 45 nominations.  $429,113,729
# 18   Nominated for 1 BAFTA Film Award. Another 38 w...  $448,130,642
# 19   Nominated for 2 Oscars. Another 18 wins & 50 n...  $436,471,036
# 20     Won 4 Oscars. Another 47 wins & 34 nominations.           N/A
# 21                                                 N/A           N/A
# 22                                                 N/A           N/A
# 23   Nominated for 1 Golden Globe. Another 22 wins ...  $336,663,349
# 24      Won 1 Oscar. Another 42 wins & 53 nominations.  $423,032,628
# 25     Won 2 Oscars. Another 33 wins & 29 nominations.   $94,240,635
# 26                                                 N/A           N/A
# 27     Won 2 Oscars. Another 58 wins & 91 nominations.  $414,984,497
# 28                           17 wins & 54 nominations.  $412,400,625
# 29   Nominated for 1 Oscar. Another 17 wins & 61 no...  $408,992,272
# ..                                                 ...           ...
# 220     Won 2 Oscars. Another 7 wins & 13 nominations.           N/A
# 221                            9 wins & 5 nominations.           N/A
# 222       Nominated for 1 Oscar. Another 1 nomination.           N/A
# 223  Nominated for 1 Oscar. Another 2 wins & 7 nomi...           N/A
# 224  Nominated for 3 Oscars. Another 3 wins & 2 nom...           N/A
# 225    Won 3 Oscars. Another 11 wins & 23 nominations.           N/A
# 226    Won 3 Oscars. Another 17 wins & 21 nominations.           N/A
# 227     Won 3 Oscars. Another 9 wins & 13 nominations.           N/A
# 228  Nominated for 5 Oscars. Another 9 wins & 8 nom...           N/A
# 229                            3 wins & 4 nominations.           N/A
# 230    Won 5 Oscars. Another 16 wins & 13 nominations.           N/A
# 231                              1 win & 1 nomination.           N/A
# 232    Won 5 Oscars. Another 30 wins & 13 nominations.           N/A
# 233    Won 5 Oscars. Another 27 wins & 18 nominations.           N/A
# 234                            3 wins & 6 nominations.           N/A
# 235      Won 1 Oscar. Another 9 wins & 16 nominations.           N/A
# 236    Won 5 Oscars. Another 33 wins & 23 nominations.           N/A
# 237     Won 1 Oscar. Another 20 wins & 16 nominations.           N/A
# 238  Nominated for 1 Oscar. Another 3 wins & 6 nomi...           N/A
# 239    Won 4 Oscars. Another 16 wins & 14 nominations.           N/A
# 240    Won 5 Oscars. Another 15 wins & 17 nominations.           N/A
# 241  Nominated for 3 Oscars. Another 5 wins & 3 nom...           N/A
# 242                                      1 nomination.           N/A
# 243      Won 1 Oscar. Another 3 wins & 19 nominations.           N/A
# 244                            3 wins & 6 nominations.   $29,200,000
# 245  Nominated for 1 Oscar. Another 4 wins & 11 nom...           N/A
# 246  Nominated for 1 BAFTA Film Award. Another 1 wi...           N/A
# 247  Nominated for 3 Oscars. Another 5 wins & 4 nom...           N/A
# 248                                     2 nominations.           N/A
# 249      Nominated for 1 Oscar. Another 7 nominations.           N/A
#
#                            Country          DVD  \
# 0                              USA  05 Apr 2016
# 1                  USA, UK, Canada  30 Jul 2019
# 2                              USA  22 Apr 2010
# 3                              USA  15 May 2018
# 4                              USA  14 Aug 2018
# 5                              USA  10 Sep 2012
# 6                              USA  20 Oct 2015
# 7                              USA  25 Sep 2012
# 8                              USA  27 Mar 2018
# 9                              USA  23 Oct 2018
# 10                             USA          N/A
# 11                         USA, UK  09 Dec 2008
# 12                             USA  04 Apr 2017
# 13                             USA  06 Jun 2017
# 14                             USA  15 Nov 2016
# 15                             USA  16 Oct 2001
# 16                             USA  21 Sep 2004
# 17                             USA  02 Oct 2015
# 18                         UK, USA  03 Dec 2012
# 19                             USA  02 Nov 2004
# 20                             USA  22 Oct 2002
# 21                             USA  01 Oct 2019
# 22                  USA, Australia  11 Jun 2019
# 23                             USA  07 Mar 2014
# 24                             USA  05 Dec 2006
# 25                             USA  07 Oct 2003
# 26                             USA  18 Sep 2018
# 27                             USA  02 Nov 2010
# 28           USA, China, Hong Kong  19 Sep 2017
# 29                             USA  24 Sep 2013
# ..                             ...          ...
# 220                            USA  12 Dec 2000
# 221                            USA  25 Aug 1998
# 222                            USA  27 Oct 1998
# 223                            USA  18 Mar 2003
# 224                            USA  27 Aug 1997
# 225                        UK, USA  20 Mar 2001
# 226                            USA  07 Aug 2006
# 227                            USA  09 Mar 1999
# 228                            USA  15 Sep 1998
# 229                        UK, USA  03 Oct 2000
# 230  USA, Italy, UK, Liechtenstein  01 Jan 1998
# 231                    Canada, USA  05 Sep 2000
# 232                            USA  09 Dec 1997
# 233                            USA  10 Apr 2001
# 234                USA, UK, Canada  01 May 2001
# 235                            USA  24 Apr 2001
# 236                            USA  28 Aug 2001
# 237                            USA  19 Jun 2001
# 238                            USA  17 Apr 2001
# 239                            USA  16 May 2000
# 240                            USA  24 Mar 1998
# 241                            USA  01 Mar 2005
# 242                            USA  28 Aug 2001
# 243                            USA  15 Jan 1999
# 244                            USA  15 Jul 2011
# 245                            USA  09 Aug 2002
# 246                            USA  07 Feb 2012
# 247                            USA  04 Oct 2005
# 248                            USA  06 Mar 2007
# 249                            USA  14 Aug 2001
#
#                                               Director  \
# 0                                          J.J. Abrams
# 1                             Anthony Russo, Joe Russo
# 2                                        James Cameron
# 3                                         Ryan Coogler
# 4                             Anthony Russo, Joe Russo
# 5                                        James Cameron
# 6                                      Colin Trevorrow
# 7                                          Joss Whedon
# 8                                         Rian Johnson
# 9                                            Brad Bird
# 10                                         Jon Favreau
# 11                                   Christopher Nolan
# 12                                      Gareth Edwards
# 13                                         Bill Condon
# 14          Andrew Stanton, Angus MacLane(co-director)
# 15                                        George Lucas
# 16                                        George Lucas
# 17                                         Joss Whedon
# 18                                   Christopher Nolan
# 19         Andrew Adamson, Kelly Asbury, Conrad Vernon
# 20                                    Steven Spielberg
# 21                                         Josh Cooley
# 22                              Anna Boden, Ryan Fleck
# 23                                    Francis Lawrence
# 24                                      Gore Verbinski
# 25                           Roger Allers, Rob Minkoff
# 26                                         J.A. Bayona
# 27                                         Lee Unkrich
# 28                                       Patty Jenkins
# 29                                         Shane Black
# ..                                                 ...
# 220                                    Taylor Hackford
# 221                                 Sylvester Stallone
# 222                                        Hal Needham
# 223                                 Sylvester Stallone
# 224                                         Mel Brooks
# 225                                        Mark Rydell
# 226                                   John G. Avildsen
# 227                                    John Guillermin
# 228                                       George Lucas
# 229                                        Jim Sharman
# 230                                         David Lean
# 231                                          Bob Clark
# 232                                       Milos Forman
# 233                                    James L. Brooks
# 234                     Richard Lester, Richard Donner
# 235                                      Arthur Hiller
# 236                                      Robert Benton
# 237                                       Mike Nichols
# 238                                      Colin Higgins
# 239                                    George Roy Hill
# 240                                   Robert Stevenson
# 241  James Algar, Samuel Armstrong, David Hand, Gra...
# 242                                     Sidney Poitier
# 243                      George Seaton, Henry Hathaway
# 244                                        Jason Winer
# 245                                        John Badham
# 246    Clyde Geronimi, Wilfred Jackson, Hamilton Luske
# 247    Clyde Geronimi, Wilfred Jackson, Hamilton Luske
# 248  Clyde Geronimi, Wilfred Jackson, Hamilton Lusk...
# 249                                   Stuart Rosenberg
#
#                                                  Genre  \
# 0                            Action, Adventure, Sci-Fi
# 1                            Action, Adventure, Sci-Fi
# 2                   Action, Adventure, Fantasy, Sci-Fi
# 3                            Action, Adventure, Sci-Fi
# 4                            Action, Adventure, Sci-Fi
# 5                                       Drama, Romance
# 6                            Action, Adventure, Sci-Fi
# 7                            Action, Adventure, Sci-Fi
# 8                   Action, Adventure, Fantasy, Sci-Fi
# 9    Animation, Action, Adventure, Comedy, Family, ...
# 10        Animation, Adventure, Drama, Family, Musical
# 11                      Action, Crime, Drama, Thriller
# 12                           Action, Adventure, Sci-Fi
# 13                   Family, Fantasy, Musical, Romance
# 14                Animation, Adventure, Comedy, Family
# 15                  Action, Adventure, Fantasy, Sci-Fi
# 16                  Action, Adventure, Fantasy, Sci-Fi
# 17                           Action, Adventure, Sci-Fi
# 18                                    Action, Thriller
# 19   Animation, Adventure, Comedy, Family, Fantasy,...
# 20                                      Family, Sci-Fi
# 21       Animation, Adventure, Comedy, Family, Fantasy
# 22                           Action, Adventure, Sci-Fi
# 23                 Action, Adventure, Sci-Fi, Thriller
# 24                          Action, Adventure, Fantasy
# 25        Animation, Adventure, Drama, Family, Musical
# 26                           Action, Adventure, Sci-Fi
# 27       Animation, Adventure, Comedy, Family, Fantasy
# 28             Action, Adventure, Fantasy, Sci-Fi, War
# 29                           Action, Adventure, Sci-Fi
# ..                                                 ...
# 220                                     Drama, Romance
# 221                                       Drama, Sport
# 222                                     Action, Comedy
# 223                                       Drama, Sport
# 224                                    Comedy, Western
# 225                                              Drama
# 226                                       Drama, Sport
# 227                            Action, Drama, Thriller
# 228                                      Comedy, Drama
# 229                                    Comedy, Musical
# 230                                Drama, Romance, War
# 231                                             Comedy
# 232                                              Drama
# 233                                      Comedy, Drama
# 234                          Action, Adventure, Sci-Fi
# 235                                     Drama, Romance
# 236                                              Drama
# 237                             Comedy, Drama, Romance
# 238                                             Comedy
# 239                   Biography, Crime, Drama, Western
# 240                   Comedy, Family, Fantasy, Musical
# 241                           Animation, Drama, Family
# 242                                      Comedy, Crime
# 243                            Action, Drama, Thriller
# 244                                    Comedy, Romance
# 245                                       Drama, Music
# 246  Animation, Adventure, Comedy, Drama, Family, R...
# 247       Animation, Family, Fantasy, Musical, Romance
# 248     Animation, Adventure, Family, Fantasy, Musical
# 249                                             Horror
#
#                                               Language Metascore  \
# 0                                              English        81
# 1                             English, Japanese, Xhosa        78
# 2                                     English, Spanish        83
# 3                English, Swahili, Nama, Xhosa, Korean        88
# 4                                              English        68
# 5                            English, Swedish, Italian        75
# 6                                              English        59
# 7                              English, Russian, Hindi        69
# 8                                              English        85
# 9                                              English        80
# 10                                             English        55
# 11                                   English, Mandarin        84
# 12                                             English        65
# 13                                             English        65
# 14                                 English, Indonesian        77
# 15                                             English        51
# 16                                             English        90
# 17                                     English, Korean        66
# 18                                     English, Arabic        78
# 19                                             English        75
# 20                                             English        91
# 21                                             English        84
# 22                                             English        64
# 23                                             English        76
# 24           English, Turkish, Greek, Mandarin, French        53
# 25                       English, Swahili, Xhosa, Zulu        88
# 26                                    English, Russian        51
# 27                                    English, Spanish        92
# 28   English, German, Dutch, French, Spanish, Chine...        76
# 29                                             English        62
# ..                                                 ...       ...
# 220                                  English, Filipino        75
# 221                                   English, Russian        40
# 222                                            English        50
# 223                                            English        57
# 224                           English, Yiddish, German        73
# 225                                            English        68
# 226                                            English        70
# 227                                            English        69
# 228                                            English        97
# 229                                            English        58
# 230                           English, Russian, French        69
# 231                                            English        40
# 232                                            English        83
# 233                                            English        79
# 234                           English, French, Russian        87
# 235                                            English        84
# 236                                            English        77
# 237                                            English        83
# 238                                    English, French        58
# 239                                   English, Spanish        66
# 240                                            English        88
# 241                                            English        91
# 242                                            English        56
# 243                                   English, Italian        42
# 244                                            English        36
# 245                                   English, Italian        77
# 246                                            English        78
# 247                                            English        85
# 248                    English, American Sign Language        76
# 249                                            English        28
#
#                                                   Plot  ... Response  Runtime  \
# 0    30 years after the defeat of Darth Vader and t...  ...     True  138 min
# 1    After the devastating events of Avengers: Infi...  ...     True  181 min
# 2    When his brother is killed in a robbery, parap...  ...     True  162 min
# 3    After the events of Captain America: Civil War...  ...     True  134 min
# 4    The Avengers and their allies must be willing ...  ...     True  149 min
# 5    84 years later, a 100 year-old woman named Ros...  ...     True  194 min
# 6    22 years after the original Jurassic Park fail...  ...     True  124 min
# 7    Nick Fury is the director of S.H.I.E.L.D., an ...  ...     True  143 min
# 8    Rey develops her newly discovered abilities wi...  ...     True  152 min
# 9    The Incredibles hero family takes on a new mis...  ...     True  118 min
# 10   After the murder of his father, a young lion p...  ...     True  118 min
# 11   Set within a year after the events of Batman B...  ...     True  152 min
# 12   All looks lost for the Rebellion against the E...  ...     True  133 min
# 13   Disney's animated classic takes on a new form,...  ...     True  129 min
# 14   Dory is a wide-eyed, blue tang fish who suffer...  ...     True   97 min
# 15   The evil Trade Federation, led by Nute Gunray ...  ...     True  136 min
# 16   The Imperial Forces, under orders from cruel D...  ...     True  121 min
# 17   Tony Stark creates the Ultron Program to prote...  ...     True  141 min
# 18   Despite his tarnished reputation after the eve...  ...     True  164 min
# 19   Shrek has rescued Princess Fiona, got married,...  ...     True   93 min
# 20   After a gentle alien becomes stranded on Earth...  ...     True  115 min
# 21   When a new toy called "Forky" joins Woody and ...  ...     True  100 min
# 22   Carol Danvers becomes one of the universe's mo...  ...     True  123 min
# 23   Twelve months after winning the 74th Hunger Ga...  ...     True  146 min
# 24   Once again we're plunged into the world of swo...  ...     True  151 min
# 25   A young lion Prince is cast out of his pride b...  ...     True   88 min
# 26   When the island's dormant volcano begins roari...  ...     True  128 min
# 27   Woody, Buzz and the whole gang are back. As th...  ...     True  103 min
# 28   Diana, princess of the Amazons, trained to be ...  ...     True  141 min
# 29   Marvel's "Iron Man 3" pits brash-but-brilliant...  ...     True  130 min
# ..                                                 ...  ...      ...      ...
# 220  Zack Mayo is a young man who has signed up for...  ...     True  124 min
# 221  Ever since his match with Clubber Lang, Rocky ...  ...     True   91 min
# 222  Bandit and Cledus are two truck-driving southe...  ...     True   96 min
# 223  Three years and 10 successful title defenses a...  ...     True   99 min
# 224  The Ultimate Western Spoof. A town where every...  ...     True   93 min
# 225  The loons are back again on Golden Pond and so...  ...     True  109 min
# 226  Rocky Balboa is a struggling boxer trying to m...  ...     True  120 min
# 227  Doug Roberts, Architect, returns from a long v...  ...     True  165 min
# 228  It's the proverbial end of the summer 1962 in ...  ...     True  110 min
# 229  While driving home during a rain filled night,...  ...     True  100 min
# 230  During the Russian Revolution, Yuri Zhivago, i...  ...     True  197 min
# 231  1954. The sexual hijinks of a group of mid-tee...  ...     True   94 min
# 232  McMurphy has a criminal past and has once agai...  ...     True  133 min
# 233  Aurora and Emma are mother and daughter who ma...  ...     True  132 min
# 234  Picking up where "Superman: The Movie" left of...  ...     True  127 min
# 235  Harvard Law student Oliver Barrett IV and musi...  ...     True  100 min
# 236  Ted Kramer is a career man for whom his work c...  ...     True  105 min
# 237  Ben has recently graduated from college, with ...  ...     True  106 min
# 238  Meet Franklin Hart ('Coleman'). The biggest 's...  ...     True  109 min
# 239  Butch and Sundance are the two leaders of the ...  ...     True  110 min
# 240  When Jane and Michael, the children of the wea...  ...     True  139 min
# 241  The animated story of Bambi, a young deer hail...  ...     True   70 min
# 242  Skip and Harry are framed for a bank robbery a...  ...     True  111 min
# 243  This precursor to later "epic" 70's disaster f...  ...     True  137 min
# 244  Arthur is a rich, alcoholic playboy with no re...  ...     True  110 min
# 245  Nineteen-year-old Brooklyn native Tony Manero ...  ...     True  118 min
# 246  Lady, a golden cocker spaniel, meets up with a...  ...     True   76 min
# 247  In a far away, long ago kingdom, Cinderella is...  ...     True   74 min
# 248  An adaptation of J. M. Barrie's story about a ...  ...     True   77 min
# 249  Based on a true story that was claimed by writ...  ...     True  117 min
#
#                                           Title   Type  \
# 0    Star Wars: Episode VII - The Force Awakens  movie
# 1                             Avengers: Endgame  movie
# 2                                        Avatar  movie
# 3                                 Black Panther  movie
# 4                        Avengers: Infinity War  movie
# 5                                       Titanic  movie
# 6                                Jurassic World  movie
# 7                                  The Avengers  movie
# 8                      Star Wars: The Last Jedi  movie
# 9                                 Incredibles 2  movie
# 10                                The Lion King  movie
# 11                              The Dark Knight  movie
# 12                 Rogue One: A Star Wars Story  movie
# 13                         Beauty and the Beast  movie
# 14                                 Finding Dory  movie
# 15    Star Wars: Episode I - The Phantom Menace  movie
# 16           Star Wars: Episode IV - A New Hope  movie
# 17                      Avengers: Age of Ultron  movie
# 18                        The Dark Knight Rises  movie
# 19                                      Shrek 2  movie
# 20                   E.T. the Extra-Terrestrial  movie
# 21                                  Toy Story 4  movie
# 22                               Captain Marvel  movie
# 23              The Hunger Games: Catching Fire  movie
# 24   Pirates of the Caribbean: Dead Man's Chest  movie
# 25                                The Lion King  movie
# 26               Jurassic World: Fallen Kingdom  movie
# 27                                  Toy Story 3  movie
# 28                                 Wonder Woman  movie
# 29                                   Iron Man 3  movie
# ..                                          ...    ...
# 220                  An Officer and a Gentleman  movie
# 221                                    Rocky IV  movie
# 222                       Smokey and the Bandit  movie
# 223                                   Rocky III  movie
# 224                             Blazing Saddles  movie
# 225                              On Golden Pond  movie
# 226                                       Rocky  movie
# 227                        The Towering Inferno  movie
# 228                           American Graffiti  movie
# 229               The Rocky Horror Picture Show  movie
# 230                              Doctor Zhivago  movie
# 231                                     Porky's  movie
# 232             One Flew Over the Cuckoo's Nest  movie
# 233                         Terms of Endearment  movie
# 234                                 Superman II  movie
# 235                                  Love Story  movie
# 236                           Kramer vs. Kramer  movie
# 237                                The Graduate  movie
# 238                                      9 to 5  movie
# 239          Butch Cassidy and the Sundance Kid  movie
# 240                                Mary Poppins  movie
# 241                                       Bambi  movie
# 242                                  Stir Crazy  movie
# 243                                     Airport  movie
# 244                                      Arthur  movie
# 245                        Saturday Night Fever  movie
# 246                          Lady and the Tramp  movie
# 247                                  Cinderella  movie
# 248                                   Peter Pan  movie
# 249                       The Amityville Horror  movie
#
#                                                Website  \
# 0                                                  N/A
# 1                                                  N/A
# 2                                                  N/A
# 3          https://www.marvel.com/movies/black-panther
# 4    http://marvel.com/movies/movie/223/avengers_in...
# 5                                                  N/A
# 6                                                  N/A
# 7                                                  N/A
# 8                                                  N/A
# 9                                                  N/A
# 10        https://movies.disney.com/the-lion-king-2019
# 11                                                 N/A
# 12                            http://www.starwars.com/
# 13   http://movies.disney.com/beauty-and-the-beast-...
# 14               http://movies.disney.com/finding-dory
# 15                                                 N/A
# 16                                                 N/A
# 17                                                 N/A
# 18                                                 N/A
# 19                                                 N/A
# 20                                                 N/A
# 21                                                 N/A
# 22            https://movies.disney.com/captain-marvel
# 23                                                 N/A
# 24                                                 N/A
# 25                                                 N/A
# 26                        http://www.jurassicworld.com
# 27                                                 N/A
# 28                         http://wonderwomanfilm.com/
# 29                                                 N/A
# ..                                                 ...
# 220                                                N/A
# 221                                                N/A
# 222                                                N/A
# 223                                                N/A
# 224                                                N/A
# 225                                                N/A
# 226                                                N/A
# 227                                                N/A
# 228                                                N/A
# 229                                                N/A
# 230                                                N/A
# 231                                                N/A
# 232                                                N/A
# 233                                                N/A
# 234                                                N/A
# 235                                                N/A
# 236                                                N/A
# 237                                                N/A
# 238                                                N/A
# 239                                                N/A
# 240                                                N/A
# 241                                                N/A
# 242                                                N/A
# 243                                                N/A
# 244                                                N/A
# 245                                                N/A
# 246                                                N/A
# 247                                                N/A
# 248                                                N/A
# 249                                                N/A
#
#                                                 Writer  Year     imdbID  \
# 0    Lawrence Kasdan, J.J. Abrams, Michael Arndt, G...  2015  tt2488496
# 1    Christopher Markus (screenplay by), Stephen Mc...  2019  tt4154796
# 2                                        James Cameron  2009  tt0499549
# 3    Ryan Coogler, Joe Robert Cole, Stan Lee (based...  2018  tt1825683
# 4    Christopher Markus (screenplay by), Stephen Mc...  2018  tt4154756
# 5                                        James Cameron  1997  tt0120338
# 6    Rick Jaffa (screenplay by), Amanda Silver (scr...  2015  tt0369610
# 7    Joss Whedon (screenplay), Zak Penn (story), Jo...  2012  tt0848228
# 8    Rian Johnson, George Lucas (based on character...  2017  tt2527336
# 9                                            Brad Bird  2018  tt3606756
# 10   Jeff Nathanson (screenplay by), Brenda Chapman...  2019  tt6105098
# 11   Jonathan Nolan (screenplay), Christopher Nolan...  2008  tt0468569
# 12   Chris Weitz (screenplay by), Tony Gilroy (scre...  2016  tt3748528
# 13   Stephen Chbosky (screenplay by), Evan Spilioto...  2017  tt2771200
# 14   Andrew Stanton (original story by), Andrew Sta...  2016  tt2277860
# 15                                        George Lucas  1999  tt0120915
# 16                                        George Lucas  1977  tt0076759
# 17   Joss Whedon, Stan Lee (based on the Marvel com...  2015  tt2395427
# 18   Jonathan Nolan (screenplay), Christopher Nolan...  2012  tt1345836
# 19   William Steig (based upon the book by), Andrew...  2004  tt0298148
# 20                                    Melissa Mathison  1982  tt0083866
# 21   John Lasseter (original story by), Andrew Stan...  2019  tt1979376
# 22   Anna Boden (screenplay by), Ryan Fleck (screen...  2019  tt4154664
# 23   Simon Beaufoy (screenplay), Michael Arndt (scr...  2013  tt1951264
# 24   Ted Elliott, Terry Rossio, Ted Elliott (charac...  2006  tt0383574
# 25   Irene Mecchi (screenplay by), Jonathan Roberts...  1994  tt0110357
# 26   Derek Connolly, Colin Trevorrow, Michael Crich...  2018  tt4881806
# 27   John Lasseter (story by), Andrew Stanton (stor...  2010  tt0435761
# 28   Allan Heinberg (screenplay by), Zack Snyder (s...  2017  tt0451279
# 29   Drew Pearce (screenplay by), Shane Black (scre...  2013  tt1300854
# ..                                                 ...   ...        ...
# 220                                Douglas Day Stewart  1982  tt0084434
# 221                                 Sylvester Stallone  1985  tt0089927
# 222  Hal Needham (story), Robert L. Levy (story), J...  1977  tt0076729
# 223                                 Sylvester Stallone  1982  tt0084602
# 224  Mel Brooks (screenplay), Norman Steinberg (scr...  1974  tt0071230
# 225  Ernest Thompson (screenplay), Ernest Thompson ...  1981  tt0082846
# 226                                 Sylvester Stallone  1976  tt0075148
# 227  Richard Martin Stern (novel), Thomas N. Scorti...  1974  tt0072308
# 228           George Lucas, Gloria Katz, Willard Huyck  1973  tt0069704
# 229  Richard O'Brien (original musical play), Jim S...  1975  tt0073629
# 230  Boris Pasternak (novel), Robert Bolt (screenplay)  1965  tt0059113
# 231                                          Bob Clark  1981  tt0084522
# 232  Lawrence Hauben (screenplay), Bo Goldman (scre...  1975  tt0073486
# 233  Larry McMurtry (based on the novel by), James ...  1983  tt0086425
# 234  Jerry Siegel (character created by: Superman),...  1980  tt0081573
# 235                                        Erich Segal  1970  tt0066011
# 236  Avery Corman (from the novel by), Robert Bento...  1979  tt0079417
# 237  Calder Willingham (screenplay), Buck Henry (sc...  1967  tt0061722
# 238  Patricia Resnick (story), Colin Higgins (scree...  1980  tt0080319
# 239                                    William Goldman  1969  tt0064115
# 240  Bill Walsh (screenplay), Don DaGradi (screenpl...  1964  tt0058331
# 241  Felix Salten (from the story by), Perce Pearce...  1942  tt0034492
# 242                                 Bruce Jay Friedman  1980  tt0081562
# 243  Arthur Hailey (from the novel by), George Seat...  1970  tt0065377
# 244   Peter Baynham (screenplay), Steve Gordon (story)  2011  tt1334512
# 245  Nik Cohn (story "Tribal Rites of the New Satur...  1977  tt0076666
# 246  Ward Greene (from the story by), Erdman Penner...  1955  tt0048280
# 247  Charles Perrault (from the original classic by...  1950  tt0042332
# 248  J.M. Barrie (play), Ted Sears (story), Erdman ...  1953  tt0046183
# 249  Sandor Stern (screenplay), Jay Anson (based on...  1979  tt0078767
#
#     imdbRating  imdbVotes
# 0          8.0    793,036
# 1          8.6    561,813
# 2          7.8  1,059,860
# 3          7.3    538,936
# 4          8.5    706,537
# 5          7.8    973,565
# 6          7.0    547,323
# 7          8.0  1,200,683
# 8          7.1    476,677
# 9          7.7    215,257
# 10         7.1    102,621
# 11         9.0  2,101,295
# 12         7.8    489,309
# 13         7.2    245,885
# 14         7.3    218,175
# 15         6.5    664,432
# 16         8.6  1,138,257
# 17         7.3    680,834
# 18         8.4  1,408,657
# 19         7.2    389,672
# 20         7.8    341,671
# 21         8.1     96,147
# 22         7.0    359,923
# 23         7.5    581,625
# 24         7.3    620,022
# 25         8.5    862,735
# 26         6.2    229,305
# 27         8.3    701,438
# 28         7.4    501,523
# 29         7.2    706,865
# ..         ...        ...
# 220        7.0     44,985
# 221        6.9    173,092
# 222        6.9     41,552
# 223        6.8    159,554
# 224        7.7    117,493
# 225        7.6     25,597
# 226        8.1    478,849
# 227        6.9     36,189
# 228        7.4     75,728
# 229        7.4    122,674
# 230        8.0     65,136
# 231        6.2     35,710
# 232        8.7    846,597
# 233        7.4     50,262
# 234        6.8     91,810
# 235        6.9     27,191
# 236        7.8    120,523
# 237        8.0    241,091
# 238        6.8     25,029
# 239        8.0    189,548
# 240        7.8    145,198
# 241        7.3    120,070
# 242        6.8     23,064
# 243        6.6     16,138
# 244        5.7     49,285
# 245        6.8     65,014
# 246        7.3    111,720
# 247        7.3    134,323
# 248        7.3    114,793
# 249        6.2     32,750
#
# [250 rows x 25 columns]

# %%
# 
movie_data = []
wrong_movies= {"MIB 3":'tt1409024',
           "Fast & Furious Presents: Hobbs & Shaw":'tt6806448',
           "Star Wars: The Force Awakens": 'tt2488496',
           "Marvel's The Avengers":'tt0848228',
           "The Divergent Series: Insurgent":'tt2908446',
           "Dr. Seuss' The Lorax":'tt1482459',
           "Monsters Vs. Aliens":'tt0892782',
           "Jackass 3-D":'tt1116184',
           "Dr. Seuss' The Grinch (2018)":'tt2709692',
           "Fantastic Four: Rise of the Silver Surfer":'tt0486576'}


for title in boxOffice_df['Title']:
    if title in wrong_movies:
        movie_id = wrong_movies[title]
        movie = requests.get(api_url + '&i=' + movie_id).json()
        if movie['Response'] == "True":
            movie_data.append(movie)
    elif "(" in title:
        year = title[-5:][:-1]
        title = title[:-6]
        movie = requests.get(api_url + '&t=' + title + '&y=' + year).json()
        if movie['Response'] == "True":
            movie_data.append(movie)
    else:
        movie = requests.get(api_url + '&t=' + title).json()
        if movie['Response'] == "True":
            movie_data.append(movie)

# %%
rotten_tomatoes = []
metascore = []
count = 0

for movie in movie_data:
    try:
        rating = movie['Ratings'][1]['Value']
        if "/" in rating:
            rating = rating[0:2]
            rotten_tomatoes.append(rating)
        else:
            rating = rating[:-1]
            rotten_tomatoes.append(rating)
    except IndexError:
        rating = '0'
        rotten_tomatoes.append(rating)

for movie in movie_data:
    score = movie['Metascore']
    if score == 'N/A':
        score = 0
        metascore.append(score)
    else:
        metascore.append(score)

# %%
movie_df = pd.DataFrame(movie_data)
movie_df['Rotten Tomatoes'] = rotten_tomatoes
movie_df['Metascore'] = metascore
movie_df.columns
movie_df = movie_df.reset_index()
movie_df['Rank'] = movie_df['index'] + 1

df = movie_df[['Rank','Title','Plot','Actors', 'Director', 'Genre', 'Poster', 
               'Rated', 'imdbRating', 'Metascore','Rotten Tomatoes']]

# %%
split_columns = ['Actors','Director','Genre']


split_actors = []
split_directors = []
split_genre = []
#split_plot = []

for column in split_columns:
    for row in df[column]:
        split_row = row.split(", ")
        if column == 'Actors':
            split_actors.append(split_row)
        elif column == 'Director':
            split_directors.append(split_row)
        else:
            split_genre.append(split_row)


#for row in df['Plot']:
#    split_row = row.split(" ")
#    split_plot.append(split_row)

split_df = df.copy()
split_df['Actors'] = split_actors
split_df['Director'] = split_directors
split_df['Genre'] = split_genre
#split_df['Plot'] = split_plot

split_df['imdbRating'] = pd.to_numeric(split_df['imdbRating'])
split_df['Metascore'] = pd.to_numeric(split_df['Metascore'])
split_df['Rotten Tomatoes'] = pd.to_numeric(split_df['Rotten Tomatoes'])

# %%
new_df = boxOffice_df.merge(split_df,left_on = 'Rank',right_on='Rank')

new_df = new_df[['Rank', 'Title_x', 'Studio', 'Opening', '% of Total', 'Theaters',
       'Average', 'Total Gross', 'Date', 'Plot', 'Actors',
       'Director', 'Genre', 'Poster', 'Rated', 'imdbRating', 'Metascore','Rotten Tomatoes']]

new_df = new_df.rename(columns={"Title_x": "Title"})

# %%
# Create list of dictionaries
movies_dict = new_df.to_dict('records')

# %%
# Declare the collection
collection = client.movie_db.movie_detail

#Drop collection if it exists to prevent duplication
collection.drop()  

# Insert all of the documents into the collection
collection.insert_many(movies_dict)

# %%
movies_dict
# Out:
# [{'Rank': 1,
#   'Title': 'Avengers: Endgame',
#   'Studio': 'Buena Vista',
#   'Opening': 357115007,
#   '% of Total': '41.6%',
#   'Theaters': '4662',
#   'Average': 76601,
#   'Total Gross': 858373000,
#   'Date': '4/26/2019',
#   'Plot': "After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#   'Actors': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth'],
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 8.6,
#   'Metascore': 78,
#   'Rotten Tomatoes': 94,
#   '_id': ObjectId('5d9cb15409caaf66d697103a')},
#  {'Rank': 2,
#   'Title': 'Avengers: Infinity War',
#   'Studio': 'Buena Vista',
#   'Opening': 257698183,
#   '% of Total': '38.0%',
#   'Theaters': '4474',
#   'Average': 57599,
#   'Total Gross': 678815482,
#   'Date': '4/27/2018',
#   'Plot': 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.',
#   'Actors': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans'],
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 8.5,
#   'Metascore': 68,
#   'Rotten Tomatoes': 85,
#   '_id': ObjectId('5d9cb15409caaf66d697103b')},
#  {'Rank': 3,
#   'Title': 'Star Wars: The Force Awakens',
#   'Studio': 'Buena Vista',
#   'Opening': 247966675,
#   '% of Total': '26.5%',
#   'Theaters': '4134',
#   'Average': 59982,
#   'Total Gross': 936662225,
#   'Date': '12/18/2015',
#   'Plot': '30 years after the defeat of Darth Vader and the Empire, Rey, a scavenger from the planet Jakku, finds a BB-8 droid that knows the whereabouts of the long lost Luke Skywalker. Rey, as well as a rogue stormtrooper and two smugglers, are thrown into the middle of a battle between the Resistance and the daunting legions of the First Order.',
#   'Actors': ['Harrison Ford', 'Mark Hamill', 'Carrie Fisher', 'Adam Driver'],
#   'Director': ['J.J. Abrams'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTAzODEzNDAzMl5BMl5BanBnXkFtZTgwMDU1MTgzNzE@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 8.0,
#   'Metascore': 81,
#   'Rotten Tomatoes': 93,
#   '_id': ObjectId('5d9cb15409caaf66d697103c')},
#  {'Rank': 4,
#   'Title': 'Star Wars: The Last Jedi',
#   'Studio': 'Buena Vista',
#   'Opening': 220009584,
#   '% of Total': '35.5%',
#   'Theaters': '4232',
#   'Average': 51987,
#   'Total Gross': 620181382,
#   'Date': '12/15/2017',
#   'Plot': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares for battle with the First Order.',
#   'Actors': ['Mark Hamill', 'Carrie Fisher', 'Adam Driver', 'Daisy Ridley'],
#   'Director': ['Rian Johnson'],
#   'Genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ1MzcxNjg4N15BMl5BanBnXkFtZTgwNzgwMjY4MzI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.1,
#   'Metascore': 85,
#   'Rotten Tomatoes': 91,
#   '_id': ObjectId('5d9cb15409caaf66d697103d')},
#  {'Rank': 5,
#   'Title': 'Jurassic World',
#   'Studio': 'Universal',
#   'Opening': 208806270,
#   '% of Total': '32.0%',
#   'Theaters': '4274',
#   'Average': 48855,
#   'Total Gross': 652270625,
#   'Date': '6/12/2015',
#   'Plot': '22 years after the original Jurassic Park failed, the new park (also known as Jurassic World) is open for business. After years of studying genetics the scientists on the park genetically engineer a new breed of dinosaur. When everything goes horribly wrong, will our heroes make it off the island?',
#   'Actors': ['Chris Pratt',
#    'Bryce Dallas Howard',
#    'Irrfan Khan',
#    "Vincent D'Onofrio"],
#   'Director': ['Colin Trevorrow'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzQ3OTY4NjAtNzM5OS00N2ZhLWJlOWUtYzYwZjNmOWRiMzcyXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.0,
#   'Metascore': 59,
#   'Rotten Tomatoes': 72,
#   '_id': ObjectId('5d9cb15409caaf66d697103e')},
#  {'Rank': 6,
#   'Title': "Marvel's The Avengers",
#   'Studio': 'Buena Vista',
#   'Opening': 207438708,
#   '% of Total': '33.3%',
#   'Theaters': '4349',
#   'Average': 47698,
#   'Total Gross': 623357910,
#   'Date': '5/4/2012',
#   'Plot': "Nick Fury is the director of S.H.I.E.L.D., an international peace-keeping agency. The agency is a who's who of Marvel Super Heroes, with Iron Man, The Incredible Hulk, Thor, Captain America, Hawkeye and Black Widow. When global security is threatened by Loki and his cohorts, Nick Fury and his team will need all their powers to save the world from disaster.",
#   'Actors': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth'],
#   'Director': ['Joss Whedon'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNjQyMjAtNTdiOS00NGYwLWFmNTAtNThmYjU5ZGI2YTI1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 8.0,
#   'Metascore': 69,
#   'Rotten Tomatoes': 92,
#   '_id': ObjectId('5d9cb15409caaf66d697103f')},
#  {'Rank': 7,
#   'Title': 'Black Panther',
#   'Studio': 'Buena Vista',
#   'Opening': 202003951,
#   '% of Total': '28.9%',
#   'Theaters': '4020',
#   'Average': 50250,
#   'Total Gross': 700059566,
#   'Date': '2/16/2018',
#   'Plot': "After the events of Captain America: Civil War, King T'Challa returns home to the reclusive, technologically advanced African nation of Wakanda to serve as his country's new leader. However, T'Challa soon finds that he is challenged for the throne from factions within his own country. When two foes conspire to destroy Wakanda, the hero known as Black Panther must team up with C.I.A. agent Everett K. Ross and members of the Dora Milaje, Wakanadan special forces, to prevent Wakanda from being dragged into a world war.",
#   'Actors': ['Chadwick Boseman',
#    'Michael B. Jordan',
#    "Lupita Nyong'o",
#    'Danai Gurira'],
#   'Director': ['Ryan Coogler'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.3,
#   'Metascore': 88,
#   'Rotten Tomatoes': 96,
#   '_id': ObjectId('5d9cb15409caaf66d6971040')},
#  {'Rank': 8,
#   'Title': 'The Lion King (2019)',
#   'Studio': 'Buena Vista',
#   'Opening': 191770759,
#   '% of Total': '35.4%',
#   'Theaters': '4725',
#   'Average': 40586,
#   'Total Gross': 541281146,
#   'Date': '7/19/2019',
#   'Plot': 'After the murder of his father, a young lion prince flees his kingdom only to learn the true meaning of responsibility and bravery.',
#   'Actors': ['Chiwetel Ejiofor',
#    'John Oliver',
#    'James Earl Jones',
#    'John Kani'],
#   'Director': ['Jon Favreau'],
#   'Genre': ['Animation', 'Adventure', 'Drama', 'Family', 'Musical'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIwMjE1Nzc4NV5BMl5BanBnXkFtZTgwNDg4OTA1NzM@._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 7.1,
#   'Metascore': 55,
#   'Rotten Tomatoes': 53,
#   '_id': ObjectId('5d9cb15409caaf66d6971041')},
#  {'Rank': 9,
#   'Title': 'Avengers: Age of Ultron',
#   'Studio': 'Buena Vista',
#   'Opening': 191271109,
#   '% of Total': '41.7%',
#   'Theaters': '4276',
#   'Average': 44731,
#   'Total Gross': 459005868,
#   'Date': '5/1/2015',
#   'Plot': "Tony Stark creates the Ultron Program to protect the world, but when the peacekeeping program becomes hostile, The Avengers go into action to try and defeat a virtually impossible enemy together. Earth's mightiest heroes must come together once again to protect the world from global extinction.",
#   'Actors': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans'],
#   'Director': ['Joss Whedon'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM4OGJmNWMtOTM4Ni00NTE3LTg3MDItZmQxYjc4N2JhNmUxXkEyXkFqcGdeQXVyNTgzMDMzMTg@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.3,
#   'Metascore': 66,
#   'Rotten Tomatoes': 75,
#   '_id': ObjectId('5d9cb15409caaf66d6971042')},
#  {'Rank': 10,
#   'Title': 'Incredibles 2',
#   'Studio': 'Buena Vista',
#   'Opening': 182687905,
#   '% of Total': '30.0%',
#   'Theaters': '4410',
#   'Average': 41426,
#   'Total Gross': 608581744,
#   'Date': '6/15/2018',
#   'Plot': 'The Incredibles hero family takes on a new mission, which involves a change in family roles: Bob Parr (Mr Incredible) must manage the house while his wife Helen (Elastigirl) goes out to save the world.',
#   'Actors': ['Craig T. Nelson', 'Holly Hunter', 'Sarah Vowell', 'Huck Milner'],
#   'Director': ['Brad Bird'],
#   'Genre': ['Animation', 'Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTEzNzY0OTg0NTdeQTJeQWpwZ15BbWU4MDU3OTg3MjUz._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 7.7,
#   'Metascore': 80,
#   'Rotten Tomatoes': 94,
#   '_id': ObjectId('5d9cb15409caaf66d6971043')},
#  {'Rank': 11,
#   'Title': 'Captain America: Civil War',
#   'Studio': 'Buena Vista',
#   'Opening': 179139142,
#   '% of Total': '43.9%',
#   'Theaters': '4226',
#   'Average': 42390,
#   'Total Gross': 408084349,
#   'Date': '5/6/2016',
#   'Plot': "With many people fearing the actions of super heroes, the government decides to push for the Hero Registration Act, a law that limits a hero's actions. This results in a division in The Avengers. Iron Man stands with this Act, claiming that their actions must be kept in check otherwise cities will continue to be destroyed, but Captain America feels that saving the world is daring enough and that they cannot rely on the government to protect the world. This escalates into an all-out war between Team Iron Man (Iron Man, Black Panther, Vision, Black Widow, War Machine, and Spider-Man) and Team Captain America (Captain America, Bucky Barnes, Falcon, Scarlet Witch, Hawkeye, and Ant Man) while a new villain emerges.",
#   'Actors': ['Chris Evans',
#    'Robert Downey Jr.',
#    'Scarlett Johansson',
#    'Sebastian Stan'],
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjQ0MTgyNjAxMV5BMl5BanBnXkFtZTgwNjUzMDkyODE@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.8,
#   'Metascore': 75,
#   'Rotten Tomatoes': 91,
#   '_id': ObjectId('5d9cb15409caaf66d6971044')},
#  {'Rank': 12,
#   'Title': 'Beauty and the Beast (2017)',
#   'Studio': 'Buena Vista',
#   'Opening': 174750616,
#   '% of Total': '34.7%',
#   'Theaters': '4210',
#   'Average': 41508,
#   'Total Gross': 504014165,
#   'Date': '3/17/2017',
#   'Plot': "Disney's animated classic takes on a new form, with a widened mythology and an all-star cast. A young prince, imprisoned in the form of a beast, can be freed only by true love. What may be his only opportunity arrives when he meets Belle, the only human girl to ever visit the castle since it was enchanted.",
#   'Actors': ['Emma Watson', 'Dan Stevens', 'Luke Evans', 'Josh Gad'],
#   'Director': ['Bill Condon'],
#   'Genre': ['Family', 'Fantasy', 'Musical', 'Romance'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUwNjUxMTM4NV5BMl5BanBnXkFtZTgwODExMDQzMTI@._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 7.2,
#   'Metascore': 65,
#   'Rotten Tomatoes': 71,
#   '_id': ObjectId('5d9cb15409caaf66d6971045')},
#  {'Rank': 13,
#   'Title': 'Iron Man 3',
#   'Studio': 'Buena Vista',
#   'Opening': 174144585,
#   '% of Total': '42.6%',
#   'Theaters': '4253',
#   'Average': 40946,
#   'Total Gross': 409013994,
#   'Date': '5/3/2013',
#   'Plot': 'Marvel\'s "Iron Man 3" pits brash-but-brilliant industrialist Tony Stark/Iron Man against an enemy whose reach knows no bounds. When Stark finds his personal world destroyed at his enemy\'s hands, he embarks on a harrowing quest to find those responsible. This journey, at every turn, will test his mettle. With his back against the wall, Stark is left to survive by his own devices, relying on his ingenuity and instincts to protect those closest to him. As he fights his way back, Stark discovers the answer to the question that has secretly haunted him: does the man make the suit or does the suit make the man?',
#   'Actors': ['Robert Downey Jr.',
#    'Gwyneth Paltrow',
#    'Don Cheadle',
#    'Guy Pearce'],
#   'Director': ['Shane Black'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjE5MzcyNjk1M15BMl5BanBnXkFtZTcwMjQ4MjcxOQ@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.2,
#   'Metascore': 62,
#   'Rotten Tomatoes': 79,
#   '_id': ObjectId('5d9cb15409caaf66d6971046')},
#  {'Rank': 14,
#   'Title': 'Harry Potter and the Deathly Hallows Part 2',
#   'Studio': 'Warner Bros.',
#   'Opening': 169189427,
#   '% of Total': '44.4%',
#   'Theaters': '4375',
#   'Average': 38672,
#   'Total Gross': 381011219,
#   'Date': '7/15/2011',
#   'Plot': "Harry, Ron, and Hermione continue their quest of finding and destroying the Dark Lord's three remaining Horcruxes, the magical items responsible for his immortality. But as the mystical Deathly Hallows are uncovered, and Voldemort finds out about their mission, the biggest battle begins and life as they know it will never be the same again.",
#   'Actors': ['Ralph Fiennes',
#    'Michael Gambon',
#    'Alan Rickman',
#    'Daniel Radcliffe'],
#   'Director': ['David Yates'],
#   'Genre': ['Adventure', 'Drama', 'Fantasy', 'Mystery'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjIyZGU4YzUtNDkzYi00ZDRhLTljYzctYTMxMDQ4M2E0Y2YxXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 8.1,
#   'Metascore': 87,
#   'Rotten Tomatoes': 96,
#   '_id': ObjectId('5d9cb15409caaf66d6971047')},
#  {'Rank': 15,
#   'Title': 'Batman v Superman: Dawn of Justice',
#   'Studio': 'Warner Bros.',
#   'Opening': 166007347,
#   '% of Total': '50.3%',
#   'Theaters': '4242',
#   'Average': 39134,
#   'Total Gross': 330360194,
#   'Date': '3/25/2016',
#   'Plot': 'The general public is concerned over having Superman on their planet and letting the "Dark Knight" - Batman - pursue the streets of Gotham. While this is happening, a power-phobic Batman tries to attack Superman.,Meanwhile Superman tries to settle on a decision, and Lex Luthor, the criminal mastermind and millionaire, tries to use his own advantages to fight the "Man of Steel".',
#   'Actors': ['Ben Affleck', 'Henry Cavill', 'Amy Adams', 'Jesse Eisenberg'],
#   'Director': ['Zack Snyder'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYThjYzcyYzItNTVjNy00NDk0LTgwMWQtYjMwNmNlNWJhMzMyXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 6.5,
#   'Metascore': 44,
#   'Rotten Tomatoes': 28,
#   '_id': ObjectId('5d9cb15409caaf66d6971048')},
#  {'Rank': 16,
#   'Title': 'The Dark Knight Rises',
#   'Studio': 'Warner Bros.',
#   'Opening': 160887295,
#   '% of Total': '35.9%',
#   'Theaters': '4404',
#   'Average': 36532,
#   'Total Gross': 448139099,
#   'Date': '7/20/2012',
#   'Plot': "Despite his tarnished reputation after the events of The Dark Knight, in which he took the rap for Dent's crimes, Batman feels compelled to intervene to assist the city and its police force which is struggling to cope with Bane's plans to destroy the city.",
#   'Actors': ['Christian Bale',
#    'Gary Oldman',
#    'Tom Hardy',
#    'Joseph Gordon-Levitt'],
#   'Director': ['Christopher Nolan'],
#   'Genre': ['Action', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 8.4,
#   'Metascore': 78,
#   'Rotten Tomatoes': 87,
#   '_id': ObjectId('5d9cb15409caaf66d6971049')},
#  {'Rank': 17,
#   'Title': 'The Dark Knight',
#   'Studio': 'Warner Bros.',
#   'Opening': 158411483,
#   '% of Total': '29.7%',
#   'Theaters': '4366',
#   'Average': 36283,
#   'Total Gross': 533345358,
#   'Date': '7/18/2008',
#   'Plot': 'Set within a year after the events of Batman Begins, Batman, Lieutenant James Gordon, and new district attorney Harvey Dent successfully begin to round up the criminals that plague Gotham City until a mysterious and sadistic criminal mastermind known only as the Joker appears in Gotham, creating a new wave of chaos. Batman\'s struggle against the Joker becomes deeply personal, forcing him to "confront everything he believes" and improve his technology to stop him. A love triangle develops between Bruce Wayne, Dent and Rachel Dawes.',
#   'Actors': ['Christian Bale',
#    'Heath Ledger',
#    'Aaron Eckhart',
#    'Michael Caine'],
#   'Director': ['Christopher Nolan'],
#   'Genre': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 9.0,
#   'Metascore': 84,
#   'Rotten Tomatoes': 94,
#   '_id': ObjectId('5d9cb15409caaf66d697104a')},
#  {'Rank': 18,
#   'Title': 'The Hunger Games: Catching Fire',
#   'Studio': 'Lionsgate',
#   'Opening': 158074286,
#   '% of Total': '37.2%',
#   'Theaters': '4163',
#   'Average': 37971,
#   'Total Gross': 424668047,
#   'Date': '11/22/2013',
#   'Plot': "Twelve months after winning the 74th Hunger Games, Katniss Everdeen and her partner Peeta Mellark must go on what is known as the Victor's Tour, wherein they visit all the districts, but before leaving, Katniss is visited by President Snow who fears that Katniss defied him a year ago during the games when she chose to die with Peeta. With both Katniss and Peeta declared the winners, it is fueling a possible uprising. He tells Katniss that while on tour she better try to make sure that she puts out the flames or else everyone she cares about will be in danger.",
#   'Actors': ['Jennifer Lawrence',
#    'Liam Hemsworth',
#    'Jack Quaid',
#    'Taylor St. Clair'],
#   'Director': ['Francis Lawrence'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTAyMjQ3OTAxMzNeQTJeQWpwZ15BbWU4MDU0NzA1MzAx._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.5,
#   'Metascore': 76,
#   'Rotten Tomatoes': 89,
#   '_id': ObjectId('5d9cb15409caaf66d697104b')},
#  {'Rank': 19,
#   'Title': 'Rogue One: A Star Wars Story',
#   'Studio': 'Buena Vista',
#   'Opening': 155081681,
#   '% of Total': '29.1%',
#   'Theaters': '4157',
#   'Average': 37306,
#   'Total Gross': 532177324,
#   'Date': '12/16/2016',
#   'Plot': 'All looks lost for the Rebellion against the Empire as they learn of the existence of a new super weapon, the Death Star. Once a possible weakness in its construction is uncovered, the Rebel Alliance must set out on a desperate mission to steal the plans for the Death Star. The future of the entire galaxy now rests upon its success.',
#   'Actors': ['Felicity Jones', 'Diego Luna', 'Alan Tudyk', 'Donnie Yen'],
#   'Director': ['Gareth Edwards'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjEwMzMxODIzOV5BMl5BanBnXkFtZTgwNzg3OTAzMDI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.8,
#   'Metascore': 65,
#   'Rotten Tomatoes': 84,
#   '_id': ObjectId('5d9cb15409caaf66d697104c')},
#  {'Rank': 20,
#   'Title': 'Captain Marvel',
#   'Studio': 'Buena Vista',
#   'Opening': 153433423,
#   '% of Total': '35.9%',
#   'Theaters': '4310',
#   'Average': 35599,
#   'Total Gross': 426829839,
#   'Date': '3/8/2019',
#   'Plot': "Carol Danvers becomes one of the universe's most powerful heroes when Earth is caught in the middle of a galactic war between two alien races.",
#   'Actors': ['Brie Larson', 'Samuel L. Jackson', 'Ben Mendelsohn', 'Jude Law'],
#   'Director': ['Anna Boden', 'Ryan Fleck'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTE0YWFmOTMtYTU2ZS00ZTIxLWE3OTEtYTNiYzBkZjViZThiXkEyXkFqcGdeQXVyODMzMzQ4OTI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.0,
#   'Metascore': 64,
#   'Rotten Tomatoes': 78,
#   '_id': ObjectId('5d9cb15409caaf66d697104d')},
#  {'Rank': 21,
#   'Title': 'The Hunger Games',
#   'Studio': 'Lionsgate',
#   'Opening': 152535747,
#   '% of Total': '37.4%',
#   'Theaters': '4137',
#   'Average': 36871,
#   'Total Gross': 408010692,
#   'Date': '3/23/2012',
#   'Plot': "In a dystopian future, the totalitarian nation of Panem is divided into 12 districts and the Capitol. Each year two young representatives from each district are selected by lottery to participate in The Hunger Games. Part entertainment, rutal retribution for a past rebellion, the televised games are broadcast throughout Panem. The 24 participants are forced to eliminate their competitors while the citizens of Panem are required to watch. When 16-year-old Katniss' young sister, Prim, is selected as District 12's female representative, Katniss volunteers to take her place. She and her male counterpart, Peeta, are pitted against bigger, stronger representatives, some of whom have trained for this their whole lives.",
#   'Actors': ['Stanley Tucci',
#    'Wes Bentley',
#    'Jennifer Lawrence',
#    'Willow Shields'],
#   'Director': ['Gary Ross'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjA4NDg3NzYxMF5BMl5BanBnXkFtZTcwNTgyNzkyNw@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.2,
#   'Metascore': 68,
#   'Rotten Tomatoes': 84,
#   '_id': ObjectId('5d9cb15409caaf66d697104e')},
#  {'Rank': 22,
#   'Title': 'Spider-Man 3',
#   'Studio': 'Sony / Columbia',
#   'Opening': 151116516,
#   '% of Total': '44.9%',
#   'Theaters': '4252',
#   'Average': 35540,
#   'Total Gross': 336530303,
#   'Date': '5/4/2007',
#   'Plot': "Peter Parker has finally managed to piece together the once-broken parts of his life, maintaining a balance between his relationship with Mary-Jane and his responsibility as Spider-Man. But more challenges arise for our young hero. Peter's old friend Harry Obsourne has set out for revenge against Peter; taking up the mantle of his late father's persona as The New Goblin, and Peter must also capture Uncle Ben's real killer, Flint Marko, who has been transformed into his toughest foe yet, the Sandman. All hope seems lost when suddenly Peter's suit turns jet-black and greatly amplifies his powers. But it also begins to greatly amplify the much darker qualities of Peter's personality that he begins to lose himself to. Peter has to reach deep inside himself to free the compassionate hero he used to be if he is to ever conquer the darkness within and face not only his greatest enemies, but also...himself.",
#   'Actors': ['Tobey Maguire',
#    'Kirsten Dunst',
#    'James Franco',
#    'Thomas Haden Church'],
#   'Director': ['Sam Raimi'],
#   'Genre': ['Action', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYTk3MDljOWQtNGI2My00OTEzLTlhYjQtOTQ4ODM2MzUwY2IwXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 6.2,
#   'Metascore': 59,
#   'Rotten Tomatoes': 63,
#   '_id': ObjectId('5d9cb15409caaf66d697104f')},
#  {'Rank': 23,
#   'Title': 'Jurassic World: Fallen Kingdom',
#   'Studio': 'Universal',
#   'Opening': 148024610,
#   '% of Total': '35.4%',
#   'Theaters': '4475',
#   'Average': 33078,
#   'Total Gross': 417719760,
#   'Date': '6/22/2018',
#   'Plot': "When the island's dormant volcano begins roaring to life, Owen and Claire mount a campaign to rescue the remaining dinosaurs from this extinction-level event.",
#   'Actors': ['Chris Pratt',
#    'Bryce Dallas Howard',
#    'Rafe Spall',
#    'Justice Smith'],
#   'Director': ['J.A. Bayona'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzIxMjYwNDEwN15BMl5BanBnXkFtZTgwMzk5MDI3NTM@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 6.2,
#   'Metascore': 51,
#   'Rotten Tomatoes': 48,
#   '_id': ObjectId('5d9cb15409caaf66d6971050')},
#  {'Rank': 24,
#   'Title': 'Furious 7',
#   'Studio': 'Universal',
#   'Opening': 147187040,
#   '% of Total': '41.7%',
#   'Theaters': '4004',
#   'Average': 36760,
#   'Total Gross': 353007020,
#   'Date': '4/3/2015',
#   'Plot': 'Dominic and his crew thought they\'d left the criminal mercenary life behind. They\'d defeated international terrorist Owen Shaw and went their separate ways. But now, Shaw\'s brother, Deckard Shaw, is out killing the crew one by one for revenge. Worse, a Somalian terrorist called Jakarde and a shady government official called "Mr. Nobody" are both competing to steal a computer terrorism program called "God\'s Eye," that can turn any technological device into a weapon. Torretto must reconvene with his team to stop Shaw and retrieve the God\'s Eye program while caught in a power struggle between the terrorist and the United States government.',
#   'Actors': ['Vin Diesel',
#    'Paul Walker',
#    'Jason Statham',
#    'Michelle Rodriguez'],
#   'Director': ['James Wan'],
#   'Genre': ['Action', 'Adventure', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQxOTA2NDUzOV5BMl5BanBnXkFtZTgwNzY2MTMxMzE@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.2,
#   'Metascore': 67,
#   'Rotten Tomatoes': 81,
#   '_id': ObjectId('5d9cb15409caaf66d6971051')},
#  {'Rank': 25,
#   'Title': 'Guardians of the Galaxy Vol. 2',
#   'Studio': 'Buena Vista',
#   'Opening': 146510104,
#   '% of Total': '37.6%',
#   'Theaters': '4347',
#   'Average': 33704,
#   'Total Gross': 389813101,
#   'Date': '5/5/2017',
#   'Plot': "After saving Xandar from Ronan's wrath, the Guardians are now recognized as heroes. Now the team must help their leader Star Lord (Chris Pratt) uncover the truth behind his true heritage. Along the way, old foes turn to allies and betrayal is blooming. And the Guardians find that they are up against a devastating new menace who is out to rule the galaxy.",
#   'Actors': ['Chris Pratt', 'Zoe Saldana', 'Dave Bautista', 'Vin Diesel'],
#   'Director': ['James Gunn'],
#   'Genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BN2MwNjJlODAtMTc1MS00NjkwLTg2NDMtYzFjZmU2MGM1YWUwXkEyXkFqcGdeQXVyMTYzMDM0NTU@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.6,
#   'Metascore': 67,
#   'Rotten Tomatoes': 84,
#   '_id': ObjectId('5d9cb15409caaf66d6971052')},
#  {'Rank': 26,
#   'Title': 'The Twilight Saga: New Moon',
#   'Studio': 'Summit Entertainment',
#   'Opening': 142839137,
#   '% of Total': '48.2%',
#   'Theaters': '4024',
#   'Average': 35497,
#   'Total Gross': 296623634,
#   'Date': '11/20/2009',
#   'Plot': "After Bella recovers from the vampire attack that almost claimed her life, she looks to celebrate her birthday with Edward and his family. However, a minor accident during the festivities results in Bella's blood being shed, a sight that proves too intense for the Cullens, who decide to leave the town of Forks, Washington for Bella and Edward's sake. Initially heartbroken, Bella finds a form of comfort in reckless living, as well as an even-closer friendship with Jacob Black. Danger in different forms awaits.",
#   'Actors': ['Kristen Stewart',
#    'Christina Jastrzembska',
#    'Robert Pattinson',
#    'Billy Burke'],
#   'Director': ['Chris Weitz'],
#   'Genre': ['Adventure', 'Drama', 'Fantasy', 'Mystery', 'Romance'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI3MjE3NDIxNF5BMl5BanBnXkFtZTcwODM3NTY5Mg@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 4.7,
#   'Metascore': 44,
#   'Rotten Tomatoes': 28,
#   '_id': ObjectId('5d9cb15409caaf66d6971053')},
#  {'Rank': 27,
#   'Title': 'The Twilight Saga: Breaking Dawn Part 2',
#   'Studio': 'Lionsgate',
#   'Opening': 141067634,
#   '% of Total': '48.3%',
#   'Theaters': '4070',
#   'Average': 34660,
#   'Total Gross': 292324737,
#   'Date': '11/16/2012',
#   'Plot': 'The final Twilight Saga begins with Bella now a vampire learning to use her abilities. And happy to see her daughter, Renesmee is flourishing. But when someone sees Renesmee do something that makes them think that she was turned. This person goes to the Volturi, because it is a violation to turn a child. And the penalty is death for both who turned the child into a vampire and the child, cause they deem a turned child too dangerous. Alice gets a vision of the Volturi coming after them. So the Cullens try to convince them that Renesmee is not a threat. So they ask friends and family to come stand with them. But when someone who has it in for the Volturi shows up and tells them they should be ready for a fight. And they get ready.',
#   'Actors': ['Kristen Stewart',
#    'Robert Pattinson',
#    'Taylor Lautner',
#    'Peter Facinelli'],
#   'Director': ['Bill Condon'],
#   'Genre': ['Adventure', 'Drama', 'Fantasy', 'Romance'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcyMzUyMzY1OF5BMl5BanBnXkFtZTcwNDQ4ODk1OA@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 5.5,
#   'Metascore': 52,
#   'Rotten Tomatoes': 49,
#   '_id': ObjectId('5d9cb15409caaf66d6971054')},
#  {'Rank': 28,
#   'Title': 'The Twilight Saga: Breaking Dawn Part 1',
#   'Studio': 'Summit Entertainment',
#   'Opening': 138122261,
#   '% of Total': '49.1%',
#   'Theaters': '4061',
#   'Average': 34012,
#   'Total Gross': 281287133,
#   'Date': '11/18/2011',
#   'Plot': "After Bella and Edward's honeymoon, things take a turn for the worse when Bella realises she is pregnant. The baby grows at an abnormally fast rate and causes many health problems to Bella. The wolf pack see the unborn child as a threat and plan to get rid of it. But the Cullens do everything they can to ensure that both Bella and the unborn child remain safe.",
#   'Actors': ['Taylor Lautner',
#    'Gil Birmingham',
#    'Billy Burke',
#    'Sarah Clarke'],
#   'Director': ['Bill Condon'],
#   'Genre': ['Action', 'Adventure', 'Drama', 'Fantasy', 'Romance', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BODgxNDE0OTAzOF5BMl5BanBnXkFtZTcwNzcwODE2Ng@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 4.9,
#   'Metascore': 45,
#   'Rotten Tomatoes': 25,
#   '_id': ObjectId('5d9cb15409caaf66d6971055')},
#  {'Rank': 29,
#   'Title': "Pirates of the Caribbean: Dead Man's Chest",
#   'Studio': 'Buena Vista',
#   'Opening': 135634554,
#   '% of Total': '32.0%',
#   'Theaters': '4133',
#   'Average': 32817,
#   'Total Gross': 423315812,
#   'Date': '7/7/2006',
#   'Plot': 'Once again we\'re plunged into the world of sword fights and "savvy" pirates. Captain Jack Sparrow is reminded he owes a debt to Davy Jones, who captains the flying Dutchman, a ghostly ship, with a crew from hell. Facing the "locker" Jack must find the heart of Davy Jones but to save himself he must get the help of quick-witted Will Turner and Elizabeth Swan. If that\'s not complicated enough, Will and Elizabeth are sentenced to hang, unless will can get Lord Cutler Beckett Jack\'s compass, Will is forced to join another crazy adventure with Jack.',
#   'Actors': ['Johnny Depp',
#    'Orlando Bloom',
#    'Keira Knightley',
#    'Jack Davenport'],
#   'Director': ['Gore Verbinski'],
#   'Genre': ['Action', 'Adventure', 'Fantasy'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcwODc1MTMxM15BMl5BanBnXkFtZTYwMDg1NzY3._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.3,
#   'Metascore': 53,
#   'Rotten Tomatoes': 53,
#   '_id': ObjectId('5d9cb15409caaf66d6971056')},
#  {'Rank': 30,
#   'Title': 'Finding Dory',
#   'Studio': 'Buena Vista',
#   'Opening': 135060273,
#   '% of Total': '27.8%',
#   'Theaters': '4305',
#   'Average': 31373,
#   'Total Gross': 486295561,
#   'Date': '6/17/2016',
#   'Plot': 'Dory is a wide-eyed, blue tang fish who suffers from memory loss every 10 seconds or so. The one thing she can remember is that she somehow became separated from her parents as a child. With help from her friends Nemo and Marlin, Dory embarks on an epic adventure to find them. Her journey brings her to the Marine Life Institute, a conservatory that houses diverse ocean species.',
#   'Actors': ['Ellen DeGeneres',
#    'Albert Brooks',
#    "Ed O'Neill",
#    'Kaitlin Olson'],
#   'Director': ['Andrew Stanton', 'Angus MacLane(co-director)'],
#   'Genre': ['Animation', 'Adventure', 'Comedy', 'Family'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzg4MjM2NDQ4MV5BMl5BanBnXkFtZTgwMzk3MTgyODE@._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 7.3,
#   'Metascore': 77,
#   'Rotten Tomatoes': 94,
#   '_id': ObjectId('5d9cb15409caaf66d6971057')},
#  {'Rank': 31,
#   'Title': 'Suicide Squad',
#   'Studio': 'Warner Bros.',
#   'Opening': 133682248,
#   '% of Total': '41.1%',
#   'Theaters': '4255',
#   'Average': 31418,
#   'Total Gross': 325100054,
#   'Date': '8/5/2016',
#   'Plot': "It feels good to be bad...Assemble a team of the world's most dangerous, incarcerated Super Villains, provide them with the most powerful arsenal at the government's disposal, and send them off on a mission to defeat an enigmatic, insuperable entity. U.S. intelligence officer Amanda Waller has determined only a secretly convened group of disparate, despicable individuals with next to nothing to lose will do. However, once they realize they weren't picked to succeed but chosen for their patent culpability when they inevitably fail, will the Suicide Squad resolve to die trying, or decide it's every man for himself?",
#   'Actors': ['Will Smith',
#    'Jaime FitzSimons',
#    'Ike Barinholtz',
#    'Margot Robbie'],
#   'Director': ['David Ayer'],
#   'Genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjM1OTMxNzUyM15BMl5BanBnXkFtZTgwNjYzMTIzOTE@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 6.0,
#   'Metascore': 40,
#   'Rotten Tomatoes': 27,
#   '_id': ObjectId('5d9cb15409caaf66d6971058')},
#  {'Rank': 32,
#   'Title': 'Deadpool',
#   'Studio': '20th Century Fox',
#   'Opening': 132434639,
#   '% of Total': '36.5%',
#   'Theaters': '3558',
#   'Average': 37222,
#   'Total Gross': 363070709,
#   'Date': '2/12/2016',
#   'Plot': 'This is the origin story of former Special Forces operative turned mercenary Wade Wilson, who after being subjected to a rogue experiment that leaves him with accelerated healing powers, adopts the alter ego Deadpool. Armed with his new abilities and a dark, twisted sense of humor, Deadpool hunts down the man who nearly destroyed his life.',
#   'Actors': ['Ryan Reynolds', 'Karan Soni', 'Ed Skrein', 'Michael Benyaer'],
#   'Director': ['Tim Miller'],
#   'Genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYzE5MjY1ZDgtMTkyNC00MTMyLThhMjAtZGI5OTE1NzFlZGJjXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg',
#   'Rated': 'R',
#   'imdbRating': 8.0,
#   'Metascore': 65,
#   'Rotten Tomatoes': 84,
#   '_id': ObjectId('5d9cb15409caaf66d6971059')},
#  {'Rank': 33,
#   'Title': 'Iron Man 2',
#   'Studio': 'Paramount',
#   'Opening': 128122480,
#   '% of Total': '41.0%',
#   'Theaters': '4380',
#   'Average': 29252,
#   'Total Gross': 312433331,
#   'Date': '5/7/2010',
#   'Plot': 'With the world now aware of his dual life as the armored superhero Iron Man, billionaire inventor Tony Stark faces pressure from the government, the press, and the public to share his technology with the military. Unwilling to let go of his invention, Stark, along with Pepper Potts, and James "Rhodey" Rhodes at his side, must forge new alliances - and confront powerful enemies.',
#   'Actors': ['Robert Downey Jr.',
#    'Gwyneth Paltrow',
#    'Don Cheadle',
#    'Scarlett Johansson'],
#   'Director': ['Jon Favreau'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM0MDgwNjMyMl5BMl5BanBnXkFtZTcwNTg3NzAzMw@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.0,
#   'Metascore': 57,
#   'Rotten Tomatoes': 73,
#   '_id': ObjectId('5d9cb15409caaf66d697105a')},
#  {'Rank': 34,
#   'Title': 'Deadpool 2',
#   'Studio': '20th Century Fox',
#   'Opening': 125507153,
#   '% of Total': '39.4%',
#   'Theaters': '4349',
#   'Average': 28859,
#   'Total Gross': 318491426,
#   'Date': '5/18/2018',
#   'Plot': 'Foul-mouthed mutant mercenary Wade Wilson (AKA. Deadpool), brings together a team of fellow mutant rogues to protect a young boy with supernatural abilities from the brutal, time-traveling cyborg, Cable.',
#   'Actors': ['Ryan Reynolds',
#    'Josh Brolin',
#    'Morena Baccarin',
#    'Julian Dennison'],
#   'Director': ['David Leitch'],
#   'Genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNjk1Njk3YjctMmMyYS00Y2I4LThhMzktN2U0MTMyZTFlYWQ5XkEyXkFqcGdeQXVyODM2ODEzMDA@._V1_SX300.jpg',
#   'Rated': 'R',
#   'imdbRating': 7.7,
#   'Metascore': 66,
#   'Rotten Tomatoes': 83,
#   '_id': ObjectId('5d9cb15409caaf66d697105b')},
#  {'Rank': 35,
#   'Title': 'Harry Potter and the Deathly Hallows Part 1',
#   'Studio': 'Warner Bros.',
#   'Opening': 125017372,
#   '% of Total': '42.2%',
#   'Theaters': '4125',
#   'Average': 30307,
#   'Total Gross': 295983305,
#   'Date': '11/19/2010',
#   'Plot': "Voldemort's power is growing stronger. He now has control over the Ministry of Magic and Hogwarts. Harry, Ron, and Hermione decide to finish Dumbledore's work and find the rest of the Horcruxes to defeat the Dark Lord. But little hope remains for the Trio, and the rest of the Wizarding World, so everything they do must go as planned.",
#   'Actors': ['Bill Nighy',
#    'Emma Watson',
#    'Richard Griffiths',
#    'Harry Melling'],
#   'Director': ['David Yates'],
#   'Genre': ['Adventure', 'Fantasy', 'Mystery'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2OTE1Mjk0N15BMl5BanBnXkFtZTcwODE3MDAwNA@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.7,
#   'Metascore': 65,
#   'Rotten Tomatoes': 77,
#   '_id': ObjectId('5d9cb15409caaf66d697105c')},
#  {'Rank': 36,
#   'Title': 'It',
#   'Studio': 'Warner Bros.',
#   'Opening': 123403419,
#   '% of Total': '37.7%',
#   'Theaters': '4103',
#   'Average': 30076,
#   'Total Gross': 327481748,
#   'Date': '9/8/2017',
#   'Plot': "In the Town of Derry, the local kids are disappearing one by one, leaving behind bloody remains. In a place known as 'The Barrens', a group of seven kids are united by their horrifying and strange encounters with an evil clown and their determination to kill It.",
#   'Actors': ['Jaeden Martell',
#    'Jeremy Ray Taylor',
#    'Sophia Lillis',
#    'Finn Wolfhard'],
#   'Director': ['Andy Muschietti'],
#   'Genre': ['Horror'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZDVkZmI0YzAtNzdjYi00ZjhhLWE1ODEtMWMzMWMzNDA0NmQ4XkEyXkFqcGdeQXVyNzYzODM3Mzg@._V1_SX300.jpg',
#   'Rated': 'R',
#   'imdbRating': 7.4,
#   'Metascore': 69,
#   'Rotten Tomatoes': 86,
#   '_id': ObjectId('5d9cb15409caaf66d697105d')},
#  {'Rank': 37,
#   'Title': 'Thor: Ragnarok',
#   'Studio': 'Buena Vista',
#   'Opening': 122744989,
#   '% of Total': '39.0%',
#   'Theaters': '4080',
#   'Average': 30085,
#   'Total Gross': 315058289,
#   'Date': '11/3/2017',
#   'Plot': 'Thor is imprisoned on the other side of the universe and finds himself in a race against time to get back to Asgard to stop Ragnarok, the destruction of his homeworld and the end of Asgardian civilization, at the hands of an all-powerful new threat, the ruthless Hela.',
#   'Actors': ['Chris Hemsworth',
#    'Tom Hiddleston',
#    'Cate Blanchett',
#    'Idris Elba'],
#   'Director': ['Taika Waititi'],
#   'Genre': ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMyNDkzMzI1OF5BMl5BanBnXkFtZTgwODcxODg5MjI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.9,
#   'Metascore': 74,
#   'Rotten Tomatoes': 92,
#   '_id': ObjectId('5d9cb15409caaf66d697105e')},
#  {'Rank': 38,
#   'Title': 'The Hunger Games: Mockingjay - Part 1',
#   'Studio': 'Lionsgate',
#   'Opening': 121897634,
#   '% of Total': '36.2%',
#   'Theaters': '4151',
#   'Average': 29366,
#   'Total Gross': 337135885,
#   'Date': '11/21/2014',
#   'Plot': 'With the Games destroyed, Katniss Everdeen, along with Gale, Finnick and Beetee, end up in the so thought "destroyed" District 13. Under the leadership of President Coin and the advice of her friends, Katniss becomes the "Mockingjay", the symbol of rebellion for the districts of Panem.',
#   'Actors': ['Jennifer Lawrence',
#    'Josh Hutcherson',
#    'Liam Hemsworth',
#    'Woody Harrelson'],
#   'Director': ['Francis Lawrence'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTcxNDI2NDAzNl5BMl5BanBnXkFtZTgwODM3MTc2MjE@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 6.6,
#   'Metascore': 64,
#   'Rotten Tomatoes': 69,
#   '_id': ObjectId('5d9cb15409caaf66d697105f')},
#  {'Rank': 39,
#   'Title': 'Shrek the Third',
#   'Studio': 'Paramount',
#   'Opening': 121629270,
#   '% of Total': '37.7%',
#   'Theaters': '4122',
#   'Average': 29507,
#   'Total Gross': 322719944,
#   'Date': '5/18/2007',
#   'Plot': "When Fiona's father and King of Far Far Away passes away, the clumsy Shrek becomes the immediate successor of the throne. However, Shrek decides to find the legitimate heir Artie in a distant kingdom with his friends Donkey and Puss in Boots to be able return to his beloved house in the swamp with the pregnant Fiona. Meanwhile, the envious and ambitious Prince Charming joins the villains of the fairytales plotting a coup d'état to become the new king.",
#   'Actors': ['Mike Myers', 'Eddie Murphy', 'Cameron Diaz', 'Antonio Banderas'],
#   'Director': ['Chris Miller', 'Raman Hui(co-director)'],
#   'Genre': ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOTgyMjc3ODk2MV5BMl5BanBnXkFtZTcwMjY0MjEzMw@@._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 6.0,
#   'Metascore': 58,
#   'Rotten Tomatoes': 41,
#   '_id': ObjectId('5d9cb15409caaf66d6971060')},
#  {'Rank': 40,
#   'Title': 'Toy Story 4',
#   'Studio': 'Buena Vista',
#   'Opening': 120908065,
#   '% of Total': '27.9%',
#   'Theaters': '4575',
#   'Average': 26428,
#   'Total Gross': 433314437,
#   'Date': '6/21/2019',
#   'Plot': 'When a new toy called "Forky" joins Woody and the gang, a road trip alongside old and new friends reveals how big the world can be for a toy.',
#   'Actors': ['Tom Hanks', 'Tim Allen', 'Annie Potts', 'Tony Hale'],
#   'Director': ['Josh Cooley'],
#   'Genre': ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTYzMDM4NzkxOV5BMl5BanBnXkFtZTgwNzM1Mzg2NzM@._V1_SX300.jpg',
#   'Rated': 'G',
#   'imdbRating': 8.1,
#   'Metascore': 84,
#   'Rotten Tomatoes': 97,
#   '_id': ObjectId('5d9cb15409caaf66d6971061')},
#  {'Rank': 41,
#   'Title': 'Spider-Man: Homecoming',
#   'Studio': 'Sony / Columbia',
#   'Opening': 117027503,
#   '% of Total': '35.0%',
#   'Theaters': '4348',
#   'Average': 26915,
#   'Total Gross': 334201140,
#   'Date': '7/7/2017',
#   'Plot': 'Thrilled by his experience with the Avengers, Peter returns home, where he lives with his Aunt May, under the watchful eye of his new mentor Tony Stark, Peter tries to fall back into his normal daily routine - distracted by thoughts of proving himself to be more than just your friendly neighborhood Spider-Man - but when the Vulture emerges as a new villain, everything that Peter holds most important will be threatened.',
#   'Actors': ['Tom Holland',
#    'Michael Keaton',
#    'Robert Downey Jr.',
#    'Marisa Tomei'],
#   'Director': ['Jon Watts'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNTk4ODQ1MzgzNl5BMl5BanBnXkFtZTgwMTMyMzM4MTI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.4,
#   'Metascore': 73,
#   'Rotten Tomatoes': 92,
#   '_id': ObjectId('5d9cb15409caaf66d6971062')},
#  {'Rank': 42,
#   'Title': 'Man of Steel',
#   'Studio': 'Warner Bros.',
#   'Opening': 116619362,
#   '% of Total': '40.1%',
#   'Theaters': '4207',
#   'Average': 27720,
#   'Total Gross': 291045518,
#   'Date': '6/14/2013',
#   'Plot': 'A young boy learns that he has extraordinary powers and is not of this Earth. As a young man, he journeys to discover where he came from and what he was sent here to do. But the hero in him must emerge if he is to save the world from annihilation and become the symbol of hope for all mankind.',
#   'Actors': ['Henry Cavill', 'Amy Adams', 'Michael Shannon', 'Diane Lane'],
#   'Director': ['Zack Snyder'],
#   'Genre': ['Action', 'Adventure'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTk5ODk1NDkxMF5BMl5BanBnXkFtZTcwNTA5OTY0OQ@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.1,
#   'Metascore': 55,
#   'Rotten Tomatoes': 56,
#   '_id': ObjectId('5d9cb15409caaf66d6971063')},
#  {'Rank': 43,
#   'Title': 'Alice in Wonderland (2010)',
#   'Studio': 'Buena Vista',
#   'Opening': 116101023,
#   '% of Total': '34.7%',
#   'Theaters': '3728',
#   'Average': 31143,
#   'Total Gross': 334191110,
#   'Date': '3/5/2010',
#   'Plot': 'Alice, an unpretentious and individual 19-year-old, is betrothed to a dunce of an English nobleman. At her engagement party, she escapes the crowd to consider whether to go through with the marriage and falls down a hole in the garden after spotting an unusual rabbit. Arriving in a strange and surreal place called "Underland," she finds herself in a world that resembles the nightmares she had as a child, filled with talking animals, villainous queens and knights, and frumious bandersnatches. Alice realizes that she is there for a reason--to conquer the horrific Jabberwocky and restore the rightful queen to her throne.',
#   'Actors': ['Johnny Depp',
#    'Mia Wasikowska',
#    'Helena Bonham Carter',
#    'Anne Hathaway'],
#   'Director': ['Tim Burton'],
#   'Genre': ['Adventure', 'Family', 'Fantasy'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTMwNjAxMTc0Nl5BMl5BanBnXkFtZTcwODc3ODk5Mg@@._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 6.4,
#   'Metascore': 53,
#   'Rotten Tomatoes': 51,
#   '_id': ObjectId('5d9cb15409caaf66d6971064')},
#  {'Rank': 44,
#   'Title': 'Minions',
#   'Studio': 'Universal',
#   'Opening': 115718405,
#   '% of Total': '34.4%',
#   'Theaters': '4301',
#   'Average': 26905,
#   'Total Gross': 336045770,
#   'Date': '7/10/2015',
#   'Plot': "Ever since the dawn of time, the Minions have lived to serve the most despicable of masters. From the T-Rex to Napoleon, the easily distracted tribe has helped the biggest and the baddest of villains. Now, join protective leader Kevin, teenage rebel Stuart, and lovable little Bob on a global road trip. They'll earn a shot to work for a new boss, the world's first female supervillain, and try to save all of Minionkind from annihilation.",
#   'Actors': ['Sandra Bullock', 'Jon Hamm', 'Michael Keaton', 'Allison Janney'],
#   'Director': ['Kyle Balda', 'Pierre Coffin'],
#   'Genre': ['Animation', 'Adventure', 'Comedy', 'Family', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg2MTMyMzU0M15BMl5BanBnXkFtZTgwOTU3ODk4NTE@._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 6.4,
#   'Metascore': 56,
#   'Rotten Tomatoes': 55,
#   '_id': ObjectId('5d9cb15409caaf66d6971065')},
#  {'Rank': 45,
#   'Title': 'Spider-Man',
#   'Studio': 'Sony / Columbia',
#   'Opening': 114844116,
#   '% of Total': '28.4%',
#   'Theaters': '3615',
#   'Average': 31769,
#   'Total Gross': 403706375,
#   'Date': '5/3/2002',
#   'Plot': 'Based on Marvel Comics\' superhero character, this is a story of Peter Parker who is a nerdy high-schooler. He was orphaned as a child, bullied by jocks, and can\'t confess his crush for his stunning neighborhood girl Mary Jane Watson. To say his life is "miserable" is an understatement. But one day while on an excursion to a laboratory a runaway radioactive spider bites him... and his life changes in a way no one could have imagined. Peter acquires a muscle-bound physique, clear vision, ability to cling to surfaces and crawl over walls, shooting webs from his wrist ... but the fun isn\'t going to last. An eccentric millionaire Norman Osborn administers a performance enhancing drug on himself and his maniacal alter ego Green Goblin emerges. Now Peter Parker has to become Spider-Man and take Green Goblin to the task... or else Goblin will kill him. They come face to face and the war begins in which only one of them will survive at the end.',
#   'Actors': ['Tobey Maguire', 'Willem Dafoe', 'Kirsten Dunst', 'James Franco'],
#   'Director': ['Sam Raimi'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
# ...
#   'Plot': "A young man finds out his long lost father is an assassin. When his father is murdered, the son is recruited into his father's old organization and trained by a man named Sloan to follow in his dad's footsteps.",
#   'Actors': ['James McAvoy',
#    'Morgan Freeman',
#    'Angelina Jolie',
#    'Terence Stamp'],
#   'Director': ['Timur Bekmambetov'],
#   'Genre': ['Action', 'Crime', 'Fantasy', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTQwNDM2MTMwMl5BMl5BanBnXkFtZTgwMjE4NjQxMTE@._V1_SX300.jpg',
#   'Rated': 'R',
#   'imdbRating': 6.7,
#   'Metascore': 64,
#   'Rotten Tomatoes': 71,
#   '_id': ObjectId('5d9cb15409caaf66d6971126')},
#  {'Rank': 238,
#   'Title': 'Coco',
#   'Studio': 'Buena Vista',
#   'Opening': 50802605,
#   '% of Total': '24.2%',
#   'Theaters': '3987',
#   'Average': 12742,
#   'Total Gross': 209726015,
#   'Date': '11/22/2017',
#   'Plot': "Despite his family's baffling generations-old ban on music, Miguel (voice of newcomer Anthony Gonzalez) dreams of becoming an accomplished musician like his idol, Ernesto de la Cruz (voice of Benjamin Bratt). Desperate to prove his talent, Miguel finds himself in the stunning and colorful Land of the Dead following a mysterious chain of events. Along the way, he meets charming trickster Hector (voice of Gael García Bernal), and together, they set off on an extraordinary journey to unlock the real story behind Miguel's family history.",
#   'Actors': ['Anthony Gonzalez',
#    'Gael García Bernal',
#    'Benjamin Bratt',
#    'Alanna Ubach'],
#   'Director': ['Lee Unkrich', 'Adrian Molina(co-director)'],
#   'Genre': ['Animation', 'Adventure', 'Family', 'Fantasy', 'Music', 'Mystery'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYjQ5NjM0Y2YtNjZkNC00ZDhkLWJjMWItN2QyNzFkMDE3ZjAxXkEyXkFqcGdeQXVyODIxMzk5NjA@._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 8.4,
#   'Metascore': 81,
#   'Rotten Tomatoes': 97,
#   '_id': ObjectId('5d9cb15409caaf66d6971127')},
#  {'Rank': 239,
#   'Title': 'Jurassic Park III',
#   'Studio': 'Universal',
#   'Opening': 50771645,
#   '% of Total': '28.0%',
#   'Theaters': '3434',
#   'Average': 14784,
#   'Total Gross': 181171875,
#   'Date': '7/18/2001',
#   'Plot': "Dr. Alan Grant is now a happy man with the previous incidents of Jurassic Park now behind him. Grant is that happy that he announce in public, that nothing on Earth can persuade him back onto the islands. Maybe nothing, except Paul Kirby. Kirby and his wife, Amanda want a plane to fly them over Isla Sorna, with Dr. Grant as their guide. But not everything Kirby says is true. When the plane lands, Dr. Grant realizes that there is another reason why they are there, that he doesn't know of. Now, Dr. Grant is stuck on an island he has never been on before, with what was a plane journey now turned into a search party.",
#   'Actors': ['Sam Neill', 'William H. Macy', 'Téa Leoni', 'Alessandro Nivola'],
#   'Director': ['Joe Johnston'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BZDMyZGJjOGItYjJkZC00MDVlLWE0Y2YtZGIwMDExYWE3MGQ3XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 5.9,
#   'Metascore': 42,
#   'Rotten Tomatoes': 49,
#   '_id': ObjectId('5d9cb15409caaf66d6971128')},
#  {'Rank': 240,
#   'Title': 'The Village',
#   'Studio': 'Buena Vista',
#   'Opening': 50746142,
#   '% of Total': '44.4%',
#   'Theaters': '3730',
#   'Average': 13604,
#   'Total Gross': 114197520,
#   'Date': '7/30/2004',
#   'Plot': "M Night Shyamalan's The Villiage revolves around a desolate town in Pennsylvania. The residents of this town live simply and without the means of a modern world - no tv, modern medications. They live by strict rules - They are not to leave the village or the monsters beyond their boundaries will surely attack them. Lucius and Ivy have an attraction - a strong one. But when Noah - a man with an intellectual disability and whom also has feelings for Ivy, finds out that the two are In love, Noah attacks Lucius. He will die if brave Ivy (who is blind) does not breach the borders and find help to save Lucius.",
#   'Actors': ['Bryce Dallas Howard',
#    'Joaquin Phoenix',
#    'Adrien Brody',
#    'William Hurt'],
#   'Director': ['M. Night Shyamalan'],
#   'Genre': ['Drama', 'Mystery', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMWExMWYxN2MtYmU1YS00Mjk5LWI3OTEtYTg3NDIwZTA2MTE2L2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 6.5,
#   'Metascore': 44,
#   'Rotten Tomatoes': 44,
#   '_id': ObjectId('5d9cb15409caaf66d6971129')},
#  {'Rank': 241,
#   'Title': 'Dunkirk',
#   'Studio': 'Warner Bros.',
#   'Opening': 50513488,
#   '% of Total': '26.9%',
#   'Theaters': '3720',
#   'Average': 13579,
#   'Total Gross': 188045546,
#   'Date': '7/21/2017',
#   'Plot': 'Evacuation of Allied soldiers from Belgium, the British Empire, and France, who were cut off and surrounded by the German army from the beaches and harbor of Dunkirk, France, between May 26- June 04, 1940, during Battle of France in World War II.',
#   'Actors': ['Fionn Whitehead',
#    'Damien Bonnard',
#    'Aneurin Barnard',
#    'Lee Armstrong'],
#   'Director': ['Christopher Nolan'],
#   'Genre': ['Action', 'Drama', 'History', 'Thriller', 'War'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BN2YyZjQ0NTEtNzU5MS00NGZkLTg0MTEtYzJmMWY3MWRhZjM2XkEyXkFqcGdeQXVyMDA4NzMyOA@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.9,
#   'Metascore': 94,
#   'Rotten Tomatoes': 92,
#   '_id': ObjectId('5d9cb15409caaf66d697112a')},
#  {'Rank': 242,
#   'Title': '2 Fast 2 Furious',
#   'Studio': 'Universal',
#   'Opening': 50472480,
#   '% of Total': '39.7%',
#   'Theaters': '3408',
#   'Average': 14810,
#   'Total Gross': 127154901,
#   'Date': '6/6/2003',
#   'Plot': "EX LAPD cop Brian O'Conner (Paul Walker) teams up with his ex-con friend Roman Pearce (Tyrese Gibson) and works with undercover U.S. Customs Service agent Monica Fuentes (Eva Mendes) to bring Miami-based drug lord Carter Verone (Cole Hauser) down.",
#   'Actors': ['Paul Walker', 'Tyrese Gibson', 'Eva Mendes', 'Cole Hauser'],
#   'Director': ['John Singleton'],
#   'Genre': ['Action', 'Crime', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMzExYjcyYWMtY2JkOC00NDUwLTg2OTgtMDI3MGY2OWQzMDE2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 5.9,
#   'Metascore': 38,
#   'Rotten Tomatoes': 36,
#   '_id': ObjectId('5d9cb15409caaf66d697112b')},
#  {'Rank': 243,
#   'Title': 'Jackass 3-D',
#   'Studio': 'Paramount',
#   'Opening': 50353641,
#   '% of Total': '43.0%',
#   'Theaters': '3081',
#   'Average': 16343,
#   'Total Gross': 117229692,
#   'Date': '10/15/2010',
#   'Plot': "'Jackass 3D' opens with the entire cast all lined up, each wearing a different color of the rainbow, in front of a rainbow colored background, each in turn being attacked in various ways. Some of the footage is slowed down for maximal effect. This is repeated again at the end of the movie with additional explosions mixed in with gallons of water to wash away the cast- chaos is resumed. Throughout the movie the team are subjected to the usual foray of physical abuse from team members or perform hilarious stunts (including some of the more stomach turning stunts such as the Sweat suit cocktail, Toy Train Eruption and Poo Cocktail Supreme - not for the weak stomached!).",
#   'Actors': ['Johnny Knoxville', 'Bam Margera', 'Ryan Dunn', 'Steve-O'],
#   'Director': ['Jeff Tremaine'],
#   'Genre': ['Documentary', 'Action', 'Comedy'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI3NTQ1NTE4OV5BMl5BanBnXkFtZTcwMzEzMzA3NA@@._V1_SX300.jpg',
#   'Rated': 'R',
#   'imdbRating': 7.0,
#   'Metascore': 56,
#   'Rotten Tomatoes': 65,
#   '_id': ObjectId('5d9cb15409caaf66d697112c')},
#  {'Rank': 244,
#   'Title': 'Mr. & Mrs. Smith',
#   'Studio': '20th Century Fox',
#   'Opening': 50342878,
#   '% of Total': '27.0%',
#   'Theaters': '3424',
#   'Average': 14702,
#   'Total Gross': 186336279,
#   'Date': '6/10/2005',
#   'Plot': 'John and Jane Smith are a normal married couple, living a normal life in a normal suburb, working normal jobs...well, if you can call secretly being assassins "normal". But neither Jane nor John knows about their spouse\'s secret, until they are surprised to find each other as targets! But on their quest to kill each other, they learn a lot more about each other than they ever did in five (or six) years of marriage.',
#   'Actors': ['Brad Pitt', 'Angelina Jolie', 'Vince Vaughn', 'Adam Brody'],
#   'Director': ['Doug Liman'],
#   'Genre': ['Action', 'Comedy', 'Crime', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTUxMzcxNzQzOF5BMl5BanBnXkFtZTcwMzQxNjUyMw@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 6.5,
#   'Metascore': 55,
#   'Rotten Tomatoes': 59,
#   '_id': ObjectId('5d9cb15409caaf66d697112d')},
#  {'Rank': 245,
#   'Title': 'Independence Day',
#   'Studio': '20th Century Fox',
#   'Opening': 50228264,
#   '% of Total': '16.4%',
#   'Theaters': '2882',
#   'Average': 17428,
#   'Total Gross': 306169268,
#   'Date': '7/3/1996',
#   'Plot': 'On July 2nd, communications systems worldwide are sent into chaos by a strange atmospheric interference. It is soon learned by the military that a number of enormous objects are on a collision course with Earth. At first thought to be meteors, they are later revealed to be gigantic spacecraft, piloted by a mysterious alien species. After attempts to communicate with the aliens go nowhere, David Levinson, an ex-scientist turned cable technician, discovers that the aliens are going to attack major points around the globe in less than a day. On July 3rd, the aliens all but obliterate New York, Los Angeles and Washington, as well as Paris, London, Houston and Moscow. The survivors set out in convoys towards Area 51, a strange government testing ground where it is rumored the military has a captured alien spacecraft of their own. The survivors devise a plan to fight back against the enslaving aliens, and July 4th becomes the day humanity will fight for its freedom. July 4th is their Independence Day...',
#   'Actors': ['Will Smith', 'Bill Pullman', 'Jeff Goldblum', 'Mary McDonnell'],
#   'Director': ['Roland Emmerich'],
#   'Genre': ['Action', 'Adventure', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMGQwNDNkMmItYWY1Yy00YTZmLWE5OTAtODU0MGZmMzQ1NDdkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.0,
#   'Metascore': 59,
#   'Rotten Tomatoes': 65,
#   '_id': ObjectId('5d9cb15409caaf66d697112e')},
#  {'Rank': 246,
#   'Title': 'A Quiet Place',
#   'Studio': 'Paramount',
#   'Opening': 50203562,
#   '% of Total': '26.7%',
#   'Theaters': '3508',
#   'Average': 14311,
#   'Total Gross': 188024361,
#   'Date': '4/6/2018',
#   'Plot': 'In a post-apocalyptic world, a family is forced to live in silence while hiding from monsters with ultra-sensitive hearing.',
#   'Actors': ['Emily Blunt',
#    'John Krasinski',
#    'Millicent Simmonds',
#    'Noah Jupe'],
#   'Director': ['John Krasinski'],
#   'Genre': ['Drama', 'Horror', 'Sci-Fi'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjI0MDMzNTQ0M15BMl5BanBnXkFtZTgwMTM5NzM3NDM@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.5,
#   'Metascore': 82,
#   'Rotten Tomatoes': 95,
#   '_id': ObjectId('5d9cb15409caaf66d697112f')},
#  {'Rank': 247,
#   'Title': 'The Boss Baby',
#   'Studio': '20th Century Fox',
#   'Opening': 50198902,
#   '% of Total': '28.7%',
#   'Theaters': '3773',
#   'Average': 13305,
#   'Total Gross': 175003033,
#   'Date': '3/31/2017',
#   'Plot': "Seven-year-old Tim Templeton has always been a boy of an overactive imagination, and for the past seven years, life was all peaches for him, getting all the love and affection from his caring parents. However, life will never be the same and Tim won't be the centre of attention anymore as the arrival of an improbable new brother named Boss Baby, dressed in a black suit complete with a tie and a briefcase, will shortly rob him of all love, as he takes over the whole Templetons' house. Nevertheless, although this may be true, soon, Tim and the new Boss in a diaper will need to put differences aside and join forces, as a sneaky scheme involving the head of Puppy Co. threatens to tilt the balance of power towards their insidiously adorable furry antagonists, not to mention that the next Pet Convention is in only two days.. Brothers, hurry up.",
#   'Actors': ['Alec Baldwin', 'Steve Buscemi', 'Jimmy Kimmel', 'Lisa Kudrow'],
#   'Director': ['Tom McGrath'],
#   'Genre': ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTg5MzUxNzgxNV5BMl5BanBnXkFtZTgwMTM2NzQ3MjI@._V1_SX300.jpg',
#   'Rated': 'PG',
#   'imdbRating': 6.3,
#   'Metascore': 50,
#   'Rotten Tomatoes': 52,
#   '_id': ObjectId('5d9cb15409caaf66d6971130')},
#  {'Rank': 248,
#   'Title': 'King Kong',
#   'Studio': 'Universal',
#   'Opening': 50130145,
#   '% of Total': '23.0%',
#   'Theaters': '3568',
#   'Average': 14049,
#   'Total Gross': 218080025,
#   'Date': '12/14/2005',
#   'Plot': "Carl Denham needs to finish his movie and has the perfect location; Skull Island. But he still needs to find a leading lady. This 'soon-to-be-unfortunate' soul is Ann Darrow. No one knows what they will encounter on this island and why it is so mysterious, but once they reach it, they will soon find out. Living on this hidden island is a giant gorilla and this beast now has Ann is its grasps. Carl and Ann's new love, Jack Driscoll must travel through the jungle looking for Kong and Ann, whilst avoiding all sorts of creatures and beasts. But Carl has another plan in mind.",
#   'Actors': ['Naomi Watts',
#    'Jack Black',
#    'Adrien Brody',
#    'Thomas Kretschmann'],
#   'Director': ['Peter Jackson'],
#   'Genre': ['Action', 'Adventure', 'Drama', 'Romance'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMjYxYmRlZWYtMzAwNC00MDA1LWJjNTItOTBjMzlhNGMzYzk3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.2,
#   'Metascore': 81,
#   'Rotten Tomatoes': 84,
#   '_id': ObjectId('5d9cb15409caaf66d6971131')},
#  {'Rank': 249,
#   'Title': 'The Great Gatsby (2013)',
#   'Studio': 'Warner Bros.',
#   'Opening': 50085185,
#   '% of Total': '34.6%',
#   'Theaters': '3535',
#   'Average': 14168,
#   'Total Gross': 144840419,
#   'Date': '5/10/2013',
#   'Plot': "An adaptation of F. Scott Fitzgerald's Long Island-set novel, where Midwesterner Nick Carraway is lured into the lavish world of his neighbor, Jay Gatsby. Soon enough, however, Carraway will see through the cracks of Gatsby's nouveau riche existence, where obsession, madness, and tragedy await.",
#   'Actors': ['Lisa Adam',
#    'Frank Aldridge',
#    'Amitabh Bachchan',
#    'Steve Bisley'],
#   'Director': ['Baz Luhrmann'],
#   'Genre': ['Drama', 'Romance'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkxNTk1ODcxNl5BMl5BanBnXkFtZTcwMDI1OTMzOQ@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 7.3,
#   'Metascore': 55,
#   'Rotten Tomatoes': 48,
#   '_id': ObjectId('5d9cb15409caaf66d6971132')},
#  {'Rank': 250,
#   'Title': 'Taken 2',
#   'Studio': '20th Century Fox',
#   'Opening': 49514769,
#   '% of Total': '35.4%',
#   'Theaters': '3661',
#   'Average': 13525,
#   'Total Gross': 139854287,
#   'Date': '10/5/2012',
#   'Plot': 'The retired CIA agent Bryan Mills invites his teenage daughter Kim and his ex-wife Lenore, who has separated from her second husband, to spend a couple of days in Istanbul where he is working. Meanwhile, the patriarch of the community of the Albanian gang of human trafficking, Murad Krasniqi, seeks revenge for the death of his son and organizes another gang to kidnap Bryan and his family. Bryan and Lenore are abducted by the Albanians, but Kim escapes and is the only hope that Bryan has to escape and save Lenore.',
#   'Actors': ['Liam Neeson', 'Maggie Grace', 'Famke Janssen', 'Leland Orser'],
#   'Director': ['Olivier Megaton'],
#   'Genre': ['Action', 'Thriller'],
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BMTkwNTQ0ODExOV5BMl5BanBnXkFtZTcwNjU3NDQwOA@@._V1_SX300.jpg',
#   'Rated': 'PG-13',
#   'imdbRating': 6.2,
#   'Metascore': 45,
#   'Rotten Tomatoes': 22,
#   '_id': ObjectId('5d9cb15409caaf66d6971133')}]
